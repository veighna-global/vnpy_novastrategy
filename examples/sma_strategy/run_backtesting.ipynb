# %%
from datetime import datetime

from vnpy_novastrategy.backtesting import (
    BacktestingEngine,
    Interval,
    OptimizationSetting
)

from sma_strategy import SmaStrategy

# %%
engine = BacktestingEngine()

engine.set_parameters(
    interval=Interval.MINUTE,
    start=datetime(2022, 1, 1),
    end=datetime.now(),
    capital=1_000_000,
)

engine.add_contract(
    "BTCUSDT.BINANCE",
    pricetick=0.01,
    size=1,
    rate=0.05 / 100,
    slippage=0.01
)

# %%
setting = {
    "fast_window": 60,
    "slow_window": 100
}

engine.add_strategy(SmaStrategy, setting)

# %%
engine.load_data()
# Out:
# 2024-07-27 23:01:11.554927	Loading history data.
# 2024-07-27 23:01:19.021301	Bar data of BTCUSDT.BINANCE loaded, total count: 1.
# 2024-07-27 23:01:19.021301	History data all loaded.

# %%
engine.run_backtesting()
# Out:
# 2024-07-27 23:01:19.112700	The strategy is inited.
# 2024-07-27 23:01:19.112700	Starting to replay history data.
# 2024-07-27 23:01:23.217267	Replaying history data finished.

# %%
engine.calculate_result()
# Out:
# 2024-07-27 23:01:23.238921	Calculating daily PnL.
# 2024-07-27 23:01:23.277374	Calculation of daily PnL finished.
#             trade_count       turnover  commission  slippage  trading_pnl  \
# date
# 2022-01-11           23  126276.585938   63.138293      0.03  -774.226562
# 2022-01-12           24       0.000000    0.000000      0.00     0.000000
# 2022-01-13           24       0.000000    0.000000      0.00     0.000000
# 2022-01-14           24       0.000000    0.000000      0.00     0.000000
# 2022-01-15           24       0.000000    0.000000      0.00     0.000000
# ...                 ...            ...         ...       ...          ...
# 2024-07-19           24       0.000000    0.000000      0.00     0.000000
# 2024-07-20           24       0.000000    0.000000      0.00     0.000000
# 2024-07-21           24       0.000000    0.000000      0.00     0.000000
# 2024-07-22           24       0.000000    0.000000      0.00     0.000000
# 2024-07-23           22       0.000000    0.000000      0.00     0.000000
#
#             holding_pnl    total_pnl      net_pnl
# date
# 2022-01-11     0.000000  -774.226562  -837.394855
# 2022-01-12  1833.566406  1833.566406  1833.566406
# 2022-01-13  -379.988281  -379.988281  -379.988281
# 2022-01-14   -87.429688   -87.429688   -87.429688
# 2022-01-15   287.441406   287.441406   287.441406
# ...                 ...          ...          ...
# 2024-07-19  2291.398438  2291.398438  2291.398438
# 2024-07-20  1005.500000  1005.500000  1005.500000
# 2024-07-21   333.898438   333.898438   333.898438
# 2024-07-22   -86.601562   -86.601562   -86.601562
# 2024-07-23  -934.296875  -934.296875  -934.296875
#
# [923 rows x 8 columns]

# %%
engine.calculate_statistics()
# Out:
# 2024-07-27 23:01:23.305042	Calculating performance statistics.
# 2024-07-27 23:01:23.311398	------------------------------
# 2024-07-27 23:01:23.311398	Start Date:	2022-01-11
# 2024-07-27 23:01:23.311398	End Date:	2024-07-23
# 2024-07-27 23:01:23.311398	Total Days:	923
# 2024-07-27 23:01:23.311398	Profit Days:	463
# 2024-07-27 23:01:23.311398	Loss Days:	460
# 2024-07-27 23:01:23.311398	Start Balance:	1,000,000.00
# 2024-07-27 23:01:23.311398	End Balance:	1,069,821.46
# 2024-07-27 23:01:23.311398	Total Return:	6.98%
# 2024-07-27 23:01:23.311398	Annual Return:	2.76%
# 2024-07-27 23:01:23.311398	Max Drawdown: 	-15,777.07
# 2024-07-27 23:01:23.311398	Max Drawdown(%): -1.57%
# 2024-07-27 23:01:23.311398	Max Drawdown Duration: 	51
# 2024-07-27 23:01:23.311398	Total PnL:	69,821.46
# 2024-07-27 23:01:23.311398	Total Commission:	8,831.03
# 2024-07-27 23:01:23.311398	Total Slippage:	5.11
# 2024-07-27 23:01:23.311398	Total Turnover:	17,662,063.84
# 2024-07-27 23:01:23.311398	Total Trades:	22149
# 2024-07-27 23:01:23.311398	Daily PnL:	75.65
# 2024-07-27 23:01:23.311398	Daily Commission:	9.57
# 2024-07-27 23:01:23.311398	Daily Slippage:	0.01
# 2024-07-27 23:01:23.311398	Daily Turnover:	19,135.50
# 2024-07-27 23:01:23.311398	Daily Trades:	23.996749729144096
# 2024-07-27 23:01:23.311398	Daily Return:	0.01%
# 2024-07-27 23:01:23.311398	Return Std:	0.10%
# 2024-07-27 23:01:23.311398	Sharpe Ratio:	1.41
# 2024-07-27 23:01:23.311398	Return Drawdown Ratio:	4.43
# 2024-07-27 23:01:23.312467	Calculation of performance statistics finished.
# {'start_date': datetime.date(2022, 1, 11),
#  'end_date': datetime.date(2024, 7, 23),
#  'total_days': 923,
#  'profit_days': 463,
#  'loss_days': 460,
#  'capital': 1000000,
#  'end_balance': 1069821.459640625,
#  'max_drawdown': -15777.069750000024,
#  'max_ddpercent': -1.5652423189429259,
#  'max_drawdown_duration': 51,
#  'total_net_pnl': 69821.459640625,
#  'daily_net_pnl': 75.64621846221561,
#  'total_commission': 8831.031921875001,
#  'daily_commission': 9.567748561078007,
#  'total_slippage': 5.11,
#  'daily_slippage': 0.005536294691224269,
#  'total_turnover': 17662063.84375,
#  'daily_turnover': 19135.49712215601,
#  'total_trade_count': 22149,
#  'daily_trade_count': 23.996749729144096,
#  'total_return': 6.982145964062503,
#  'annual_return': 2.7610869738708703,
#  'daily_return': 0.007402981589226815,
#  'return_std': 0.0999532114614465,
#  'sharpe_ratio': 1.4149997044203597,
#  'return_drawdown_ratio': 4.42550237445866}

# %%
engine.show_chart()

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("fast_window", 40, 100, 5)
setting.add_parameter("slow_window", 80, 300, 10)

engine.run_bf_optimization(setting)
# Out:
# 2024-07-27 22:55:17.212148	Starting optimization with brute force algorithm
# 2024-07-27 22:55:17.212148	Parameter optimization space: 299
# 100%|██████████| 299/299 [05:14<00:00,  1.05s/it]
# 2024-07-27 23:00:31.410163	Optimization with brute force algorithm complete, 314 seconds elapsed
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 60, 'slow_window': 100}, Target Value: 1.4149997044203597
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 65, 'slow_window': 90}, Target Value: 1.4116336373741865
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 55, 'slow_window': 100}, Target Value: 1.318056710809762
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 65, 'slow_window': 100}, Target Value: 1.2510405659414254
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 55, 'slow_window': 90}, Target Value: 1.0407366473965483
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 60, 'slow_window': 90}, Target Value: 1.0161814304044938
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 60, 'slow_window': 80}, Target Value: 0.9808581348555467
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 70, 'slow_window': 80}, Target Value: 0.9656632940253331
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 65, 'slow_window': 80}, Target Value: 0.9620180672605282
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 70, 'slow_window': 90}, Target Value: 0.9254248513700183
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 100}, Target Value: 0.8734656846051323
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 100}, Target Value: 0.8725533006225924
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 70, 'slow_window': 100}, Target Value: 0.8196521965122748
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 50, 'slow_window': 100}, Target Value: 0.732342344241905
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 50, 'slow_window': 90}, Target Value: 0.6943386667296184
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 75, 'slow_window': 100}, Target Value: 0.6773149179644945
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 90, 'slow_window': 100}, Target Value: 0.5635233884782082
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 90}, Target Value: 0.5321382767511315
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 85, 'slow_window': 100}, Target Value: 0.5186311172983271
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 95, 'slow_window': 100}, Target Value: 0.4859831495292302
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 75, 'slow_window': 90}, Target Value: 0.48465343273095557
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 90}, Target Value: 0.4271333286840385
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 80, 'slow_window': 100}, Target Value: 0.2858938644948936
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 80}, Target Value: 0.26787534736045626
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 80, 'slow_window': 90}, Target Value: 0.266388064829225
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 55, 'slow_window': 80}, Target Value: 0.2349921086585584
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 80}, Target Value: 0.19345049078560803
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 85, 'slow_window': 90}, Target Value: 0.15116313091317107
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 75, 'slow_window': 80}, Target Value: 0.14818984398183677
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 50, 'slow_window': 80}, Target Value: 0.005807884677342352
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 40, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 45, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 50, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 50, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 50, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 50, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.013973	Parameters: {'fast_window': 50, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 50, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 55, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 60, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 65, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 70, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 75, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 80}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 80, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 90}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 100}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 110}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 120}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 130}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 140}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 150}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 160}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 170}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 180}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 190}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 200}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 210}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 220}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 230}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 240}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 250}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 260}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 270}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 280}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 290}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 300}, Target Value: -0.49734296254087634
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 80}, Target Value: -0.7303274169926663
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 90, 'slow_window': 80}, Target Value: -0.8723880797009903
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 100, 'slow_window': 90}, Target Value: -1.1509048539398572
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 85, 'slow_window': 80}, Target Value: -1.2702703976102139
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 80}, Target Value: -1.3701234040760142
# 2024-07-27 23:00:35.014962	Parameters: {'fast_window': 95, 'slow_window': 90}, Target Value: -1.4991843885227039
# [("{'fast_window': 60, 'slow_window': 100}",
#   1.4149997044203597,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 463,
#    'loss_days': 460,
#    'capital': 1000000,
#    'end_balance': 1069821.459640625,
#    'max_drawdown': -15777.069750000024,
#    'max_ddpercent': -1.5652423189429259,
#    'max_drawdown_duration': 51,
#    'total_net_pnl': 69821.459640625,
#    'daily_net_pnl': 75.64621846221561,
#    'total_commission': 8831.031921875001,
#    'daily_commission': 9.567748561078007,
#    'total_slippage': 5.11,
#    'daily_slippage': 0.005536294691224269,
#    'total_turnover': 17662063.84375,
#    'daily_turnover': 19135.49712215601,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 6.982145964062503,
#    'annual_return': 2.7610869738708703,
#    'daily_return': 0.007402981589226815,
#    'return_std': 0.0999532114614465,
#    'sharpe_ratio': 1.4149997044203597,
#    'return_drawdown_ratio': 4.42550237445866}),
#  ("{'fast_window': 65, 'slow_window': 90}",
#   1.4116336373741865,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 468,
#    'loss_days': 455,
#    'capital': 1000000,
#    'end_balance': 1068809.3984238282,
#    'max_drawdown': -16497.842785156332,
#    'max_ddpercent': -1.6352075391790515,
#    'max_drawdown_duration': 51,
#    'total_net_pnl': 68809.39842382813,
#    'daily_net_pnl': 74.5497274364335,
#    'total_commission': 11234.033919921876,
#    'daily_commission': 12.171217681388814,
#    'total_slippage': 6.470000000000001,
#    'daily_slippage': 0.007009750812567715,
#    'total_turnover': 22468067.83984375,
#    'daily_turnover': 24342.43536277763,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 6.880939842382827,
#    'annual_return': 2.7210650514298287,
#    'daily_return': 0.007215476184651533,
#    'return_std': 0.09765386379269114,
#    'sharpe_ratio': 1.4116336373741865,
#    'return_drawdown_ratio': 4.170811864308604}),
#  ("{'fast_window': 55, 'slow_window': 100}",
#   1.318056710809762,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 458,
#    'loss_days': 465,
#    'capital': 1000000,
#    'end_balance': 1063529.2153945311,
#    'max_drawdown': -13971.135593749932,
#    'max_ddpercent': -1.3860850501065043,
#    'max_drawdown_duration': 47,
#    'total_net_pnl': 63529.215394531246,
#    'daily_net_pnl': 68.82905243177817,
#    'total_commission': 8970.75085546875,
#    'daily_commission': 9.719123353703955,
#    'total_slippage': 5.1899999999999995,
#    'daily_slippage': 0.005622968580715059,
#    'total_turnover': 17941501.7109375,
#    'daily_turnover': 19438.24670740791,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 6.352921539453105,
#    'annual_return': 2.512260413759895,
#    'daily_return': 0.006741568499854534,
#    'return_std': 0.09771771145183542,
#    'sharpe_ratio': 1.318056710809762,
#    'return_drawdown_ratio': 4.547176209709925}),
#  ("{'fast_window': 65, 'slow_window': 100}",
#   1.2510405659414254,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 456,
#    'loss_days': 467,
#    'capital': 1000000,
#    'end_balance': 1062417.6740878907,
#    'max_drawdown': -13759.137392578064,
#    'max_ddpercent': -1.3500081307790937,
#    'max_drawdown_duration': 201,
#    'total_net_pnl': 62417.67408789063,
#    'daily_net_pnl': 67.62478232707544,
#    'total_commission': 8930.576380859377,
#    'daily_commission': 9.67559737904591,
#    'total_slippage': 5.23,
#    'daily_slippage': 0.0056663055254604555,
#    'total_turnover': 17861152.76171875,
#    'daily_turnover': 19351.19475809182,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 6.241767408789056,
#    'annual_return': 2.4683045549382507,
#    'daily_return': 0.006564907635881427,
#    'return_std': 0.10025445032830231,
#    'sharpe_ratio': 1.2510405659414254,
#    'return_drawdown_ratio': 4.536452562902663}),
#  ("{'fast_window': 55, 'slow_window': 90}",
#   1.0407366473965483,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 453,
#    'loss_days': 470,
#    'capital': 1000000,
#    'end_balance': 1049086.7799248046,
#    'max_drawdown': -21924.629976562574,
#    'max_ddpercent': -2.17633468359041,
#    'max_drawdown_duration': 57,
#    'total_net_pnl': 49086.779924804694,
#    'daily_net_pnl': 53.18177673326619,
#    'total_commission': 10364.403903320313,
#    'daily_commission': 11.229039981928834,
#    'total_slippage': 5.99,
#    'daily_slippage': 0.006489707475622969,
#    'total_turnover': 20728807.806640625,
#    'daily_turnover': 22458.079963857665,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 4.908677992480448,
#    'annual_return': 1.9411348507642077,
#    'daily_return': 0.0052955093357125475,
#    'return_std': 0.09721053261400193,
#    'sharpe_ratio': 1.0407366473965483,
#    'return_drawdown_ratio': 2.2388874967230215}),
#  ("{'fast_window': 60, 'slow_window': 90}",
#   1.0161814304044938,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 457,
#    'loss_days': 466,
#    'capital': 1000000,
#    'end_balance': 1048601.6701591797,
#    'max_drawdown': -24626.732152343844,
#    'max_ddpercent': -2.4439568806031953,
#    'max_drawdown_duration': 51,
#    'total_net_pnl': 48601.67015917969,
#    'daily_net_pnl': 52.65619735555762,
#    'total_commission': 10967.70148144531,
#    'daily_commission': 11.882666827134681,
#    'total_slippage': 6.3100000000000005,
#    'daily_slippage': 0.006836403033586133,
#    'total_turnover': 21935402.962890625,
#    'daily_turnover': 23765.333654269365,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 4.860167015917982,
#    'annual_return': 1.9219512034778585,
#    'daily_return': 0.00521011753980956,
#    'return_std': 0.09795411808957652,
#    'sharpe_ratio': 1.0161814304044938,
#    'return_drawdown_ratio': 1.9735330639292326}),
#  ("{'fast_window': 60, 'slow_window': 80}",
#   0.9808581348555467,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 455,
#    'loss_days': 468,
#    'capital': 1000000,
#    'end_balance': 1047114.4628632813,
#    'max_drawdown': -21092.47365234373,
#    'max_ddpercent': -2.093337585666684,
#    'max_drawdown_duration': 57,
#    'total_net_pnl': 47114.46286328125,
#    'daily_net_pnl': 51.044921845375136,
#    'total_commission': 13444.116199218752,
#    'daily_commission': 14.565673021905473,
#    'total_slippage': 7.709999999999999,
#    'daily_slippage': 0.008353196099674972,
#    'total_turnover': 26888232.3984375,
#    'daily_turnover': 29131.346043810943,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 4.711446286328136,
#    'annual_return': 1.8631396473561967,
#    'daily_return': 0.005056349025527391,
#    'return_std': 0.09848663028935692,
#    'sharpe_ratio': 0.9808581348555467,
#    'return_drawdown_ratio': 2.233709693791465}),
#  ("{'fast_window': 70, 'slow_window': 80}",
#   0.9656632940253331,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 457,
#    'loss_days': 466,
#    'capital': 1000000,
#    'end_balance': 1046177.9725390625,
#    'max_drawdown': -20719.618949218653,
#    'max_ddpercent': -2.0542287388931992,
#    'max_drawdown_duration': 57,
#    'total_net_pnl': 46177.97253906251,
#    'daily_net_pnl': 50.03030610949351,
#    'total_commission': 16238.0271484375,
#    'daily_commission': 17.59266213265168,
#    'total_slippage': 9.43,
#    'daily_slippage': 0.010216684723726976,
#    'total_turnover': 32476054.296875,
#    'daily_turnover': 35185.32426530336,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 4.617797253906253,
#    'annual_return': 1.8261061729965138,
#    'daily_return': 0.004874097368658756,
#    'return_std': 0.09643060894462484,
#    'sharpe_ratio': 0.9656632940253331,
#    'return_drawdown_ratio': 2.2287076153398035}),
#  ("{'fast_window': 65, 'slow_window': 80}",
#   0.9620180672605282,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 458,
#    'loss_days': 465,
#    'capital': 1000000,
#    'end_balance': 1046252.6161816407,
#    'max_drawdown': -21458.415867187432,
#    'max_ddpercent': -2.1281900786553094,
#    'max_drawdown_duration': 57,
#    'total_net_pnl': 46252.61618164063,
#    'daily_net_pnl': 50.11117679484359,
#    'total_commission': 14140.425224609375,
#    'daily_commission': 15.320070665882312,
#    'total_slippage': 8.149999999999999,
#    'daily_slippage': 0.008829902491874321,
#    'total_turnover': 28280850.44921875,
#    'daily_turnover': 30640.141331764626,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 4.625261618164056,
#    'annual_return': 1.8290579530117883,
#    'daily_return': 0.004904482268443923,
#    'return_std': 0.09739942040845963,
#    'sharpe_ratio': 0.9620180672605282,
#    'return_drawdown_ratio': 2.155453434583053}),
#  ("{'fast_window': 70, 'slow_window': 90}",
#   0.9254248513700183,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 464,
#    'loss_days': 459,
#    'capital': 1000000,
#    'end_balance': 1047056.6825429688,
#    'max_drawdown': -12943.612585937488,
#    'max_ddpercent': -1.2846581897614062,
#    'max_drawdown_duration': 26,
#    'total_net_pnl': 47056.68254296875,
#    'daily_net_pnl': 50.98232128165628,
#    'total_commission': 11742.87808203125,
#    'daily_commission': 12.722511464822588,
#    'total_slippage': 6.83,
#    'daily_slippage': 0.007399783315276273,
#    'total_turnover': 23485756.1640625,
#    'daily_turnover': 25445.02292964518,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 4.70566825429688,
#    'annual_return': 1.8608547267804563,
#    'daily_return': 0.004965058525428587,
#    'return_std': 0.10250136442512803,
#    'sharpe_ratio': 0.9254248513700183,
#    'return_drawdown_ratio': 3.63551382819455}),
#  ("{'fast_window': 45, 'slow_window': 100}",
#   0.8734656846051323,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 451,
#    'loss_days': 472,
#    'capital': 1000000,
#    'end_balance': 1040797.0152167969,
#    'max_drawdown': -16595.42966796877,
#    'max_ddpercent': -1.5870104393673194,
#    'max_drawdown_duration': 31,
#    'total_net_pnl': 40797.01521679688,
#    'daily_net_pnl': 44.20044985568459,
#    'total_commission': 8964.321189453127,
#    'daily_commission': 9.712157301682694,
#    'total_slippage': 5.23,
#    'daily_slippage': 0.0056663055254604555,
#    'total_turnover': 17928642.37890625,
#    'daily_turnover': 19424.314603365383,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 4.079701521679691,
#    'annual_return': 1.6133164197324887,
#    'daily_return': 0.004400718463719721,
#    'return_std': 0.09625519316890913,
#    'sharpe_ratio': 0.8734656846051323,
#    'return_drawdown_ratio': 2.4583283490116656}),
#  ("{'fast_window': 40, 'slow_window': 100}",
#   0.8725533006225924,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 455,
#    'loss_days': 468,
#    'capital': 1000000,
#    'end_balance': 1042210.0452246094,
#    'max_drawdown': -12919.020527343731,
#    'max_ddpercent': -1.283243502403638,
#    'max_drawdown_duration': 45,
#    'total_net_pnl': 42210.04522460938,
#    'daily_net_pnl': 45.731359939988494,
#    'total_commission': 9221.950556640624,
#    'daily_commission': 9.991279042947589,
#    'total_slippage': 5.43,
#    'daily_slippage': 0.005882990249187432,
#    'total_turnover': 18443901.11328125,
#    'daily_turnover': 19982.55808589518,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 4.221004522460947,
#    'annual_return': 1.6691946378095839,
#    'daily_return': 0.004535759732426454,
#    'return_std': 0.09931263563194082,
#    'sharpe_ratio': 0.8725533006225924,
#    'return_drawdown_ratio': 3.2672790584448546}),
#  ("{'fast_window': 70, 'slow_window': 100}",
#   0.8196521965122748,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 451,
#    'loss_days': 472,
#    'capital': 1000000,
#    'end_balance': 1041684.1711230469,
#    'max_drawdown': -15130.846160156303,
#    'max_ddpercent': -1.5018663573236155,
#    'max_drawdown_duration': 51,
#    'total_net_pnl': 41684.17112304688,
#    'daily_net_pnl': 45.16161551792728,
#    'total_commission': 9741.521220703125,
#    'daily_commission': 10.554194171942715,
#    'total_slippage': 5.71,
#    'daily_slippage': 0.006186348862405201,
#    'total_turnover': 19483042.44140625,
#    'daily_turnover': 21108.38834388543,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': 4.16841711230469,
#    'annual_return': 1.6483989664043464,
#    'daily_return': 0.004407716183043795,
#    'return_std': 0.1027378439249858,
#    'sharpe_ratio': 0.8196521965122748,
# ...
#    'daily_slippage': 1.0834236186348863e-05,
#    'total_turnover': 41892.96875,
#    'daily_turnover': 45.387831798483205,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -2.423798773437502,
#    'annual_return': -0.9584903058555669,
#    'daily_return': -0.0026752048193173883,
#    'return_std': 0.10276553637826058,
#    'sharpe_ratio': -0.49734296254087634,
#    'return_drawdown_ratio': -0.4286305580020586}),
#  ("{'fast_window': 100, 'slow_window': 220}",
#   -0.49734296254087634,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 450,
#    'loss_days': 473,
#    'capital': 1000000,
#    'end_balance': 975762.012265625,
#    'max_drawdown': -56547.5029296875,
#    'max_ddpercent': -5.512799498305812,
#    'max_drawdown_duration': 478,
#    'total_net_pnl': -24237.987734374998,
#    'daily_net_pnl': -26.26000837960455,
#    'total_commission': 20.946484375,
#    'daily_commission': 0.022693915899241603,
#    'total_slippage': 0.01,
#    'daily_slippage': 1.0834236186348863e-05,
#    'total_turnover': 41892.96875,
#    'daily_turnover': 45.387831798483205,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -2.423798773437502,
#    'annual_return': -0.9584903058555669,
#    'daily_return': -0.0026752048193173883,
#    'return_std': 0.10276553637826058,
#    'sharpe_ratio': -0.49734296254087634,
#    'return_drawdown_ratio': -0.4286305580020586}),
#  ("{'fast_window': 100, 'slow_window': 230}",
#   -0.49734296254087634,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 450,
#    'loss_days': 473,
#    'capital': 1000000,
#    'end_balance': 975762.012265625,
#    'max_drawdown': -56547.5029296875,
#    'max_ddpercent': -5.512799498305812,
#    'max_drawdown_duration': 478,
#    'total_net_pnl': -24237.987734374998,
#    'daily_net_pnl': -26.26000837960455,
#    'total_commission': 20.946484375,
#    'daily_commission': 0.022693915899241603,
#    'total_slippage': 0.01,
#    'daily_slippage': 1.0834236186348863e-05,
#    'total_turnover': 41892.96875,
#    'daily_turnover': 45.387831798483205,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -2.423798773437502,
#    'annual_return': -0.9584903058555669,
#    'daily_return': -0.0026752048193173883,
#    'return_std': 0.10276553637826058,
#    'sharpe_ratio': -0.49734296254087634,
#    'return_drawdown_ratio': -0.4286305580020586}),
#  ("{'fast_window': 100, 'slow_window': 240}",
#   -0.49734296254087634,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 450,
#    'loss_days': 473,
#    'capital': 1000000,
#    'end_balance': 975762.012265625,
#    'max_drawdown': -56547.5029296875,
#    'max_ddpercent': -5.512799498305812,
#    'max_drawdown_duration': 478,
#    'total_net_pnl': -24237.987734374998,
#    'daily_net_pnl': -26.26000837960455,
#    'total_commission': 20.946484375,
#    'daily_commission': 0.022693915899241603,
#    'total_slippage': 0.01,
#    'daily_slippage': 1.0834236186348863e-05,
#    'total_turnover': 41892.96875,
#    'daily_turnover': 45.387831798483205,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -2.423798773437502,
#    'annual_return': -0.9584903058555669,
#    'daily_return': -0.0026752048193173883,
#    'return_std': 0.10276553637826058,
#    'sharpe_ratio': -0.49734296254087634,
#    'return_drawdown_ratio': -0.4286305580020586}),
#  ("{'fast_window': 100, 'slow_window': 250}",
#   -0.49734296254087634,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 450,
#    'loss_days': 473,
#    'capital': 1000000,
#    'end_balance': 975762.012265625,
#    'max_drawdown': -56547.5029296875,
#    'max_ddpercent': -5.512799498305812,
#    'max_drawdown_duration': 478,
#    'total_net_pnl': -24237.987734374998,
#    'daily_net_pnl': -26.26000837960455,
#    'total_commission': 20.946484375,
#    'daily_commission': 0.022693915899241603,
#    'total_slippage': 0.01,
#    'daily_slippage': 1.0834236186348863e-05,
#    'total_turnover': 41892.96875,
#    'daily_turnover': 45.387831798483205,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -2.423798773437502,
#    'annual_return': -0.9584903058555669,
#    'daily_return': -0.0026752048193173883,
#    'return_std': 0.10276553637826058,
#    'sharpe_ratio': -0.49734296254087634,
#    'return_drawdown_ratio': -0.4286305580020586}),
#  ("{'fast_window': 100, 'slow_window': 260}",
#   -0.49734296254087634,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 450,
#    'loss_days': 473,
#    'capital': 1000000,
#    'end_balance': 975762.012265625,
#    'max_drawdown': -56547.5029296875,
#    'max_ddpercent': -5.512799498305812,
#    'max_drawdown_duration': 478,
#    'total_net_pnl': -24237.987734374998,
#    'daily_net_pnl': -26.26000837960455,
#    'total_commission': 20.946484375,
#    'daily_commission': 0.022693915899241603,
#    'total_slippage': 0.01,
#    'daily_slippage': 1.0834236186348863e-05,
#    'total_turnover': 41892.96875,
#    'daily_turnover': 45.387831798483205,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -2.423798773437502,
#    'annual_return': -0.9584903058555669,
#    'daily_return': -0.0026752048193173883,
#    'return_std': 0.10276553637826058,
#    'sharpe_ratio': -0.49734296254087634,
#    'return_drawdown_ratio': -0.4286305580020586}),
#  ("{'fast_window': 100, 'slow_window': 270}",
#   -0.49734296254087634,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 450,
#    'loss_days': 473,
#    'capital': 1000000,
#    'end_balance': 975762.012265625,
#    'max_drawdown': -56547.5029296875,
#    'max_ddpercent': -5.512799498305812,
#    'max_drawdown_duration': 478,
#    'total_net_pnl': -24237.987734374998,
#    'daily_net_pnl': -26.26000837960455,
#    'total_commission': 20.946484375,
#    'daily_commission': 0.022693915899241603,
#    'total_slippage': 0.01,
#    'daily_slippage': 1.0834236186348863e-05,
#    'total_turnover': 41892.96875,
#    'daily_turnover': 45.387831798483205,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -2.423798773437502,
#    'annual_return': -0.9584903058555669,
#    'daily_return': -0.0026752048193173883,
#    'return_std': 0.10276553637826058,
#    'sharpe_ratio': -0.49734296254087634,
#    'return_drawdown_ratio': -0.4286305580020586}),
#  ("{'fast_window': 100, 'slow_window': 280}",
#   -0.49734296254087634,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 450,
#    'loss_days': 473,
#    'capital': 1000000,
#    'end_balance': 975762.012265625,
#    'max_drawdown': -56547.5029296875,
#    'max_ddpercent': -5.512799498305812,
#    'max_drawdown_duration': 478,
#    'total_net_pnl': -24237.987734374998,
#    'daily_net_pnl': -26.26000837960455,
#    'total_commission': 20.946484375,
#    'daily_commission': 0.022693915899241603,
#    'total_slippage': 0.01,
#    'daily_slippage': 1.0834236186348863e-05,
#    'total_turnover': 41892.96875,
#    'daily_turnover': 45.387831798483205,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -2.423798773437502,
#    'annual_return': -0.9584903058555669,
#    'daily_return': -0.0026752048193173883,
#    'return_std': 0.10276553637826058,
#    'sharpe_ratio': -0.49734296254087634,
#    'return_drawdown_ratio': -0.4286305580020586}),
#  ("{'fast_window': 100, 'slow_window': 290}",
#   -0.49734296254087634,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 450,
#    'loss_days': 473,
#    'capital': 1000000,
#    'end_balance': 975762.012265625,
#    'max_drawdown': -56547.5029296875,
#    'max_ddpercent': -5.512799498305812,
#    'max_drawdown_duration': 478,
#    'total_net_pnl': -24237.987734374998,
#    'daily_net_pnl': -26.26000837960455,
#    'total_commission': 20.946484375,
#    'daily_commission': 0.022693915899241603,
#    'total_slippage': 0.01,
#    'daily_slippage': 1.0834236186348863e-05,
#    'total_turnover': 41892.96875,
#    'daily_turnover': 45.387831798483205,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -2.423798773437502,
#    'annual_return': -0.9584903058555669,
#    'daily_return': -0.0026752048193173883,
#    'return_std': 0.10276553637826058,
#    'sharpe_ratio': -0.49734296254087634,
#    'return_drawdown_ratio': -0.4286305580020586}),
#  ("{'fast_window': 100, 'slow_window': 300}",
#   -0.49734296254087634,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 450,
#    'loss_days': 473,
#    'capital': 1000000,
#    'end_balance': 975762.012265625,
#    'max_drawdown': -56547.5029296875,
#    'max_ddpercent': -5.512799498305812,
#    'max_drawdown_duration': 478,
#    'total_net_pnl': -24237.987734374998,
#    'daily_net_pnl': -26.26000837960455,
#    'total_commission': 20.946484375,
#    'daily_commission': 0.022693915899241603,
#    'total_slippage': 0.01,
#    'daily_slippage': 1.0834236186348863e-05,
#    'total_turnover': 41892.96875,
#    'daily_turnover': 45.387831798483205,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -2.423798773437502,
#    'annual_return': -0.9584903058555669,
#    'daily_return': -0.0026752048193173883,
#    'return_std': 0.10276553637826058,
#    'sharpe_ratio': -0.49734296254087634,
#    'return_drawdown_ratio': -0.4286305580020586}),
#  ("{'fast_window': 100, 'slow_window': 80}",
#   -0.7303274169926663,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 461,
#    'loss_days': 462,
#    'capital': 1000000,
#    'end_balance': 963400.2039726563,
#    'max_drawdown': -44338.7753945312,
#    'max_ddpercent': -4.404289168382182,
#    'max_drawdown_duration': 858,
#    'total_net_pnl': -36599.79602734375,
#    'daily_net_pnl': -39.6530834532435,
#    'total_commission': 10991.594464843749,
#    'daily_commission': 11.9085530496682,
#    'total_slippage': 6.3500000000000005,
#    'daily_slippage': 0.006879739978331528,
#    'total_turnover': 21983188.9296875,
#    'daily_turnover': 23817.106099336404,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -3.6599796027343756,
#    'annual_return': -1.447337546043388,
#    'daily_return': -0.004018293629321763,
#    'return_std': 0.1051164042447545,
#    'sharpe_ratio': -0.7303274169926663,
#    'return_drawdown_ratio': -0.8254579812291797}),
#  ("{'fast_window': 90, 'slow_window': 80}",
#   -0.8723880797009903,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 461,
#    'loss_days': 462,
#    'capital': 1000000,
#    'end_balance': 956928.9989921876,
#    'max_drawdown': -47456.15083593759,
#    'max_ddpercent': -4.733006975549219,
#    'max_drawdown_duration': 738,
#    'total_net_pnl': -43071.00100781249,
#    'daily_net_pnl': -46.66413977011104,
#    'total_commission': 15010.9989765625,
#    'daily_commission': 16.263270830511917,
#    'total_slippage': 8.67,
#    'daily_slippage': 0.009393282773564464,
#    'total_turnover': 30021997.953125,
#    'daily_turnover': 32526.541661023835,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -4.307100100781247,
#    'annual_return': -1.703241101609052,
#    'daily_return': -0.0047630170034344025,
#    'return_std': 0.1043082937489181,
#    'sharpe_ratio': -0.8723880797009903,
#    'return_drawdown_ratio': -0.9075957541671434}),
#  ("{'fast_window': 100, 'slow_window': 90}",
#   -1.1509048539398572,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 449,
#    'loss_days': 474,
#    'capital': 1000000,
#    'end_balance': 941609.3558242187,
#    'max_drawdown': -64635.89297265629,
#    'max_ddpercent': -6.429996741478505,
#    'max_drawdown_duration': 858,
#    'total_net_pnl': -58390.64417578125,
#    'daily_net_pnl': -63.26180300734697,
#    'total_commission': 14599.096050781249,
#    'daily_commission': 15.817005472135698,
#    'total_slippage': 8.469999999999999,
#    'daily_slippage': 0.009176598049837486,
#    'total_turnover': 29198192.1015625,
#    'daily_turnover': 31634.0109442714,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -5.8390644175781325,
#    'annual_return': -2.3090558097681675,
#    'daily_return': -0.00649699503008759,
#    'return_std': 0.10784984991595811,
#    'sharpe_ratio': -1.1509048539398572,
#    'return_drawdown_ratio': -0.903378007022862}),
#  ("{'fast_window': 85, 'slow_window': 80}",
#   -1.2702703976102139,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 446,
#    'loss_days': 477,
#    'capital': 1000000,
#    'end_balance': 939425.5588876953,
#    'max_drawdown': -70073.80007714848,
#    'max_ddpercent': -6.975293932403276,
#    'max_drawdown_duration': 763,
#    'total_net_pnl': -60574.441112304674,
#    'daily_net_pnl': -65.62778018667895,
#    'total_commission': 22201.855565429687,
#    'daily_commission': 24.05401469710692,
#    'total_slippage': 12.65,
#    'daily_slippage': 0.013705308775731312,
#    'total_turnover': 44403711.130859375,
#    'daily_turnover': 48108.02939421384,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -6.05744411123047,
#    'annual_return': -2.395413976813783,
#    'daily_return': -0.006915405270384157,
#    'return_std': 0.1040082744826131,
#    'sharpe_ratio': -1.2702703976102139,
#    'return_drawdown_ratio': -0.8644377933780473}),
#  ("{'fast_window': 95, 'slow_window': 80}",
#   -1.3701234040760142,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 463,
#    'loss_days': 460,
#    'capital': 1000000,
#    'end_balance': 932864.7104560547,
#    'max_drawdown': -72548.9457119141,
#    'max_ddpercent': -7.224576141486021,
#    'max_drawdown_duration': 857,
#    'total_net_pnl': -67135.28954394531,
#    'daily_net_pnl': -72.73595833580207,
#    'total_commission': 12633.415090820312,
#    'daily_commission': 13.687340293413122,
#    'total_slippage': 7.3100000000000005,
#    'daily_slippage': 0.007919826652221018,
#    'total_turnover': 25266830.181640625,
#    'daily_turnover': 27374.680586826245,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -6.713528954394532,
#    'annual_return': -2.6548624792567757,
#    'daily_return': -0.0075078624760061136,
#    'return_std': 0.10468948327978156,
#    'sharpe_ratio': -1.3701234040760142,
#    'return_drawdown_ratio': -0.9253792578948566}),
#  ("{'fast_window': 95, 'slow_window': 90}",
#   -1.4991843885227039,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 451,
#    'loss_days': 472,
#    'capital': 1000000,
#    'end_balance': 925586.9839267578,
#    'max_drawdown': -76578.30886230466,
#    'max_ddpercent': -7.6490773253446775,
#    'max_drawdown_duration': 913,
#    'total_net_pnl': -74413.0160732422,
#    'daily_net_pnl': -80.62081914760802,
#    'total_commission': 19650.948182617187,
#    'daily_commission': 21.290301389617753,
#    'total_slippage': 11.23,
#    'daily_slippage': 0.012166847237269773,
#    'total_turnover': 39301896.365234375,
#    'daily_turnover': 42580.60277923551,
#    'total_trade_count': 22149,
#    'daily_trade_count': 23.996749729144096,
#    'total_return': -7.441301607324213,
#    'annual_return': -2.9426598988876904,
#    'daily_return': -0.00828852246957176,
#    'return_std': 0.10562543250187106,
#    'sharpe_ratio': -1.4991843885227039,
#    'return_drawdown_ratio': -0.9717244632163936})]
