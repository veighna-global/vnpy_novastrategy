# %%
from datetime import datetime

from vnpy_novastrategy.backtesting import (
    BacktestingEngine,
    Interval,
    OptimizationSetting
)

from turtle_strategy import TurtleStrategy

# %%
engine = BacktestingEngine()

engine.set_parameters(
    interval=Interval.MINUTE,
    start=datetime(2022, 1, 1),
    end=datetime.now(),
    capital=1_000_000,
)

engine.add_contract(
    "BTCUSDT.BINANCE",
    pricetick=0.01,
    size=1,
    rate=0.05 / 100,
    slippage=0.01
)

# %%
setting = {
    "entry_window": 70,
    "exit_window": 60,
    "atr_window": 12,
    "risk_level": 5000
}

engine.add_strategy(TurtleStrategy, setting)

# %%
engine.load_data()
# Out:
# 2024-08-15 15:21:17.032938	Loading history data.
# 2024-08-15 15:21:23.333393	Bar data of BTCUSDT.BINANCE loaded, total count: 1343392.
# 2024-08-15 15:21:23.334397	History data all loaded.

# %%
engine.run_backtesting()

# %%
for trade in engine.trades.values():
    print(f"{trade.tradeid} [{trade.datetime}] {trade.direction.value} {trade.volume} @ {trade.price}")

# %%
engine.calculate_result()

# %%
engine.calculate_statistics()

# %%
engine.show_chart()

# %%
setting = OptimizationSetting()
setting.set_target("return_drawdown_ratio")
setting.add_parameter("entry_window", 10, 100, 10)
setting.add_parameter("exit_window", 10, 100, 10)
# setting.add_parameter("entry_window", 70)
# setting.add_parameter("exit_window", 60)
setting.add_parameter("atr_window", 12)
# setting.add_parameter("atr_window", 4, 40, 4)

engine.run_bf_optimization(setting, max_workers=6)
# Out:
# 2024-08-15 15:34:59.107053	Starting optimization with brute force algorithm
# 2024-08-15 15:34:59.107053	Parameter optimization space: 100
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 100/100 [08:19<00:00,  5.00s/it]
# 2024-08-15 15:43:18.737561	Optimization with brute force algorithm complete, 499 seconds elapsed
# 2024-08-15 15:43:22.005134	Parameters: {'entry_window': 10, 'exit_window': 60, 'atr_window': 12}, Target Value: 4.677986169710819
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 60, 'exit_window': 60, 'atr_window': 12}, Target Value: 4.40445846693109
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 20, 'exit_window': 60, 'atr_window': 12}, Target Value: 4.228151001344942
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 30, 'exit_window': 60, 'atr_window': 12}, Target Value: 4.1364423813527855
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 40, 'exit_window': 60, 'atr_window': 12}, Target Value: 4.094830049134074
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 50, 'exit_window': 60, 'atr_window': 12}, Target Value: 4.033351907111737
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 70, 'exit_window': 60, 'atr_window': 12}, Target Value: 3.9819398988681747
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 10, 'exit_window': 70, 'atr_window': 12}, Target Value: 3.7172029778826863
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 70, 'exit_window': 70, 'atr_window': 12}, Target Value: 3.633793822566263
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 60, 'exit_window': 70, 'atr_window': 12}, Target Value: 3.589792481529191
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 20, 'exit_window': 70, 'atr_window': 12}, Target Value: 3.3806370358612288
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 30, 'exit_window': 70, 'atr_window': 12}, Target Value: 3.3346370030226415
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 50, 'exit_window': 70, 'atr_window': 12}, Target Value: 3.3064143012331493
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 40, 'exit_window': 70, 'atr_window': 12}, Target Value: 3.3031761041333696
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 80, 'exit_window': 60, 'atr_window': 12}, Target Value: 3.04067711287471
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 60, 'exit_window': 80, 'atr_window': 12}, Target Value: 2.9135896675440454
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 100, 'exit_window': 60, 'atr_window': 12}, Target Value: 2.8986452905126345
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 80, 'exit_window': 80, 'atr_window': 12}, Target Value: 2.8922996149714995
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 70, 'exit_window': 80, 'atr_window': 12}, Target Value: 2.8739285177992757
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 10, 'exit_window': 80, 'atr_window': 12}, Target Value: 2.8514469753388894
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 80, 'exit_window': 70, 'atr_window': 12}, Target Value: 2.787985645584596
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 20, 'exit_window': 80, 'atr_window': 12}, Target Value: 2.6924264700572196
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 90, 'exit_window': 60, 'atr_window': 12}, Target Value: 2.6854859965918907
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 100, 'exit_window': 70, 'atr_window': 12}, Target Value: 2.6185377067680724
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 50, 'exit_window': 80, 'atr_window': 12}, Target Value: 2.5938570064870765
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 30, 'exit_window': 80, 'atr_window': 12}, Target Value: 2.5519448826795426
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 40, 'exit_window': 80, 'atr_window': 12}, Target Value: 2.547198507585319
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 90, 'exit_window': 70, 'atr_window': 12}, Target Value: 2.533240116227586
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 90, 'exit_window': 80, 'atr_window': 12}, Target Value: 2.4919667792744065
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 60, 'exit_window': 100, 'atr_window': 12}, Target Value: 2.443989166507933
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 70, 'exit_window': 100, 'atr_window': 12}, Target Value: 2.4284612938122856
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 80, 'exit_window': 100, 'atr_window': 12}, Target Value: 2.3727441828137583
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 100, 'exit_window': 80, 'atr_window': 12}, Target Value: 2.3699111712054712
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 90, 'exit_window': 100, 'atr_window': 12}, Target Value: 2.3318488321678417
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 50, 'exit_window': 100, 'atr_window': 12}, Target Value: 2.2488806402866564
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 100, 'exit_window': 100, 'atr_window': 12}, Target Value: 2.220830070550279
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 10, 'exit_window': 100, 'atr_window': 12}, Target Value: 2.1892909714165194
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 60, 'exit_window': 20, 'atr_window': 12}, Target Value: 2.169872119225531
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 100, 'exit_window': 10, 'atr_window': 12}, Target Value: 2.143369986733747
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 40, 'exit_window': 100, 'atr_window': 12}, Target Value: 2.1409839173863396
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 20, 'exit_window': 100, 'atr_window': 12}, Target Value: 2.130723988549328
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 30, 'exit_window': 100, 'atr_window': 12}, Target Value: 2.11577142411864
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 80, 'exit_window': 10, 'atr_window': 12}, Target Value: 2.0636313443697833
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 90, 'exit_window': 10, 'atr_window': 12}, Target Value: 2.057252065948564
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 90, 'exit_window': 90, 'atr_window': 12}, Target Value: 2.0146004952918193
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 60, 'exit_window': 90, 'atr_window': 12}, Target Value: 1.9714049971717273
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 70, 'exit_window': 90, 'atr_window': 12}, Target Value: 1.935584999521563
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 100, 'exit_window': 90, 'atr_window': 12}, Target Value: 1.9325872375349642
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 80, 'exit_window': 90, 'atr_window': 12}, Target Value: 1.9092391940324367
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 50, 'exit_window': 90, 'atr_window': 12}, Target Value: 1.8770719102253042
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 10, 'exit_window': 90, 'atr_window': 12}, Target Value: 1.8745376528931161
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 40, 'exit_window': 90, 'atr_window': 12}, Target Value: 1.829719897026749
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 30, 'exit_window': 90, 'atr_window': 12}, Target Value: 1.7955818385078546
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 60, 'exit_window': 10, 'atr_window': 12}, Target Value: 1.7910138639971065
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 20, 'exit_window': 90, 'atr_window': 12}, Target Value: 1.7855793137870337
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 100, 'exit_window': 20, 'atr_window': 12}, Target Value: 1.7809180798208772
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 60, 'exit_window': 50, 'atr_window': 12}, Target Value: 1.7628043379815794
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 80, 'exit_window': 20, 'atr_window': 12}, Target Value: 1.7611965967665335
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 90, 'exit_window': 50, 'atr_window': 12}, Target Value: 1.7526995320314802
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 70, 'exit_window': 10, 'atr_window': 12}, Target Value: 1.7508767594904735
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 90, 'exit_window': 20, 'atr_window': 12}, Target Value: 1.6451974278184471
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 100, 'exit_window': 50, 'atr_window': 12}, Target Value: 1.5830906157657345
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 70, 'exit_window': 20, 'atr_window': 12}, Target Value: 1.5801846436734608
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 80, 'exit_window': 50, 'atr_window': 12}, Target Value: 1.3683032693305823
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 70, 'exit_window': 50, 'atr_window': 12}, Target Value: 1.3572657981315088
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 100, 'exit_window': 40, 'atr_window': 12}, Target Value: 1.1186781874049705
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 90, 'exit_window': 40, 'atr_window': 12}, Target Value: 1.0879920698404377
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 80, 'exit_window': 40, 'atr_window': 12}, Target Value: 1.004589161867169
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 60, 'exit_window': 40, 'atr_window': 12}, Target Value: 1.0040139340552827
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 10, 'exit_window': 50, 'atr_window': 12}, Target Value: 0.9654158176077633
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 50, 'exit_window': 20, 'atr_window': 12}, Target Value: 0.931659174042486
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 20, 'exit_window': 50, 'atr_window': 12}, Target Value: 0.8539100982907581
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 70, 'exit_window': 40, 'atr_window': 12}, Target Value: 0.8135649132153919
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 30, 'exit_window': 50, 'atr_window': 12}, Target Value: 0.7767922510024506
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 40, 'exit_window': 50, 'atr_window': 12}, Target Value: 0.735257308960083
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 20, 'exit_window': 20, 'atr_window': 12}, Target Value: 0.727554421974619
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 10, 'exit_window': 20, 'atr_window': 12}, Target Value: 0.7014556422392831
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 50, 'exit_window': 50, 'atr_window': 12}, Target Value: 0.6567502841252026
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 50, 'exit_window': 10, 'atr_window': 12}, Target Value: 0.6068360974275678
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 80, 'exit_window': 30, 'atr_window': 12}, Target Value: 0.6064708026015417
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 60, 'exit_window': 30, 'atr_window': 12}, Target Value: 0.5579635566016349
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 100, 'exit_window': 30, 'atr_window': 12}, Target Value: 0.5303400688898335
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 40, 'exit_window': 20, 'atr_window': 12}, Target Value: 0.4809905100277746
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 90, 'exit_window': 30, 'atr_window': 12}, Target Value: 0.4555088451108775
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 70, 'exit_window': 30, 'atr_window': 12}, Target Value: 0.4529405137549558
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 30, 'exit_window': 20, 'atr_window': 12}, Target Value: 0.3293576747551859
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 20, 'exit_window': 40, 'atr_window': 12}, Target Value: 0.24397816812059764
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 10, 'exit_window': 40, 'atr_window': 12}, Target Value: 0.2080743330590028
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 30, 'exit_window': 40, 'atr_window': 12}, Target Value: 0.1864960216768912
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 40, 'exit_window': 10, 'atr_window': 12}, Target Value: 0.17543939945896278
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 50, 'exit_window': 40, 'atr_window': 12}, Target Value: 0.17488211133915268
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 40, 'exit_window': 40, 'atr_window': 12}, Target Value: 0.10803014657572335
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 30, 'exit_window': 10, 'atr_window': 12}, Target Value: -0.05008487655624519
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 50, 'exit_window': 30, 'atr_window': 12}, Target Value: -0.13372781757397012
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 40, 'exit_window': 30, 'atr_window': 12}, Target Value: -0.18443265552323976
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 20, 'exit_window': 10, 'atr_window': 12}, Target Value: -0.2447428326270828
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 30, 'exit_window': 30, 'atr_window': 12}, Target Value: -0.40665741960935314
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 20, 'exit_window': 30, 'atr_window': 12}, Target Value: -0.41435799584842736
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 10, 'exit_window': 10, 'atr_window': 12}, Target Value: -0.42381193395589034
# 2024-08-15 15:43:22.006115	Parameters: {'entry_window': 10, 'exit_window': 30, 'atr_window': 12}, Target Value: -0.42728201784152803
# [("{'entry_window': 10, 'exit_window': 60, 'atr_window': 12}",
#   4.677986169710819,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 473,
#    'loss_days': 450,
#    'capital': 1000000,
#    'end_balance': 2914516.1800897354,
#    'max_drawdown': -409260.761069776,
#    'max_ddpercent': -18.82279890078014,
#    'max_drawdown_duration': 96,
#    'total_net_pnl': 1914516.1800897364,
#    'daily_net_pnl': 2074.232047767862,
#    'total_commission': 200205.15071416995,
#    'daily_commission': 216.9069888560888,
#    'total_slippage': 143.78570000000002,
#    'daily_slippage': 0.15578082340195018,
#    'total_turnover': 400410301.42833984,
#    'daily_turnover': 433813.9777121775,
#    'total_trade_count': 439,
#    'daily_trade_count': 0.47562296858071507,
#    'total_return': 191.45161800897355,
#    'annual_return': 75.70946974352692,
#    'daily_return': 0.11691038987361152,
#    'return_std': 1.6509397130555683,
#    'sharpe_ratio': 1.3529081920422066,
#    'return_drawdown_ratio': 4.677986169710819}),
#  ("{'entry_window': 60, 'exit_window': 60, 'atr_window': 12}",
#   4.40445846693109,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 466,
#    'loss_days': 453,
#    'capital': 1000000,
#    'end_balance': 2829073.297317518,
#    'max_drawdown': -415277.6807978323,
#    'max_ddpercent': -19.871901529615332,
#    'max_drawdown_duration': 96,
#    'total_net_pnl': 1829073.2973175193,
#    'daily_net_pnl': 1981.66121052819,
#    'total_commission': 194387.54536841798,
#    'daily_commission': 210.60405782060454,
#    'total_slippage': 139.15789999999998,
#    'daily_slippage': 0.15076695557963163,
#    'total_turnover': 388775090.73683596,
#    'daily_turnover': 421208.11564120906,
#    'total_trade_count': 433,
#    'daily_trade_count': 0.46912242686890576,
#    'total_return': 182.9073297317518,
#    'annual_return': 72.33063418427888,
#    'daily_return': 0.11368670311085688,
#    'return_std': 1.7091117724105427,
#    'sharpe_ratio': 1.2708246753059076,
#    'return_drawdown_ratio': 4.40445846693109}),
#  ("{'entry_window': 20, 'exit_window': 60, 'atr_window': 12}",
#   4.228151001344942,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 472,
#    'loss_days': 451,
#    'capital': 1000000,
#    'end_balance': 2874336.1106253415,
#    'max_drawdown': -443299.2364816512,
#    'max_ddpercent': -20.44104986473402,
#    'max_drawdown_duration': 96,
#    'total_net_pnl': 1874336.110625342,
#    'daily_net_pnl': 2030.7000115117464,
#    'total_commission': 199018.95686137697,
#    'daily_commission': 215.62183841969335,
#    'total_slippage': 141.7789,
#    'daily_slippage': 0.15360660888407365,
#    'total_turnover': 398037913.7227539,
#    'daily_turnover': 431243.67683938664,
#    'total_trade_count': 439,
#    'daily_trade_count': 0.47562296858071507,
#    'total_return': 187.43361106253414,
#    'annual_return': 74.12055042017872,
#    'daily_return': 0.11547476615232173,
#    'return_std': 1.6635498947270395,
#    'sharpe_ratio': 1.3261653988675224,
#    'return_drawdown_ratio': 4.228151001344942}),
#  ("{'entry_window': 30, 'exit_window': 60, 'atr_window': 12}",
#   4.1364423813527855,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 471,
#    'loss_days': 452,
#    'capital': 1000000,
#    'end_balance': 2850601.8643255467,
#    'max_drawdown': -447389.7358435644,
#    'max_ddpercent': -20.776087770860336,
#    'max_drawdown_duration': 96,
#    'total_net_pnl': 1850601.8643255471,
#    'daily_net_pnl': 2004.985768500051,
#    'total_commission': 199173.08867289062,
#    'daily_commission': 215.78882846467022,
#    'total_slippage': 141.9729,
#    'daily_slippage': 0.15381679306608886,
#    'total_turnover': 398346177.3457812,
#    'daily_turnover': 431577.65692934045,
#    'total_trade_count': 439,
#    'daily_trade_count': 0.47562296858071507,
#    'total_return': 185.06018643255467,
#    'annual_return': 73.18198055025184,
#    'daily_return': 0.11450804126892891,
#    'return_std': 1.6722555375862103,
#    'sharpe_ratio': 1.308216960590896,
#    'return_drawdown_ratio': 4.1364423813527855}),
#  ("{'entry_window': 40, 'exit_window': 60, 'atr_window': 12}",
#   4.094830049134074,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 471,
#    'loss_days': 452,
#    'capital': 1000000,
#    'end_balance': 2831984.9340063855,
#    'max_drawdown': -447389.7358435653,
#    'max_ddpercent': -20.90207392942767,
#    'max_drawdown_duration': 96,
#    'total_net_pnl': 1831984.9340063867,
#    'daily_net_pnl': 1984.8157464857927,
#    'total_commission': 199126.6655701758,
#    'daily_commission': 215.73853257873867,
#    'total_slippage': 141.9389,
#    'daily_slippage': 0.15377995666305525,
#    'total_turnover': 398253331.14035153,
#    'daily_turnover': 431477.0651574773,
#    'total_trade_count': 439,
#    'daily_trade_count': 0.47562296858071507,
#    'total_return': 183.19849340063854,
#    'annual_return': 72.44577474673139,
#    'daily_return': 0.113798149985518,
#    'return_std': 1.6869382858143447,
#    'sharpe_ratio': 1.2887908354847726,
#    'return_drawdown_ratio': 4.094830049134074}),
#  ("{'entry_window': 50, 'exit_window': 60, 'atr_window': 12}",
#   4.033351907111737,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 468,
#    'loss_days': 453,
#    'capital': 1000000,
#    'end_balance': 2802996.357818163,
#    'max_drawdown': -447021.83180174837,
#    'max_ddpercent': -21.106197184783227,
#    'max_drawdown_duration': 96,
#    'total_net_pnl': 1802996.357818164,
#    'daily_net_pnl': 1953.4088383728754,
#    'total_commission': 199750.05982089846,
#    'daily_commission': 216.4139326336928,
#    'total_slippage': 142.74489999999997,
#    'daily_slippage': 0.15465319609967496,
#    'total_turnover': 399500119.6417969,
#    'daily_turnover': 432827.86526738555,
#    'total_trade_count': 439,
#    'daily_trade_count': 0.47562296858071507,
#    'total_return': 180.29963578181628,
#    'annual_return': 71.2994226006099,
#    'daily_return': 0.11268342808849283,
#    'return_std': 1.7015727107283625,
#    'sharpe_ratio': 1.265190642323278,
#    'return_drawdown_ratio': 4.033351907111737}),
#  ("{'entry_window': 70, 'exit_window': 60, 'atr_window': 12}",
#   3.9819398988681747,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 449,
#    'loss_days': 451,
#    'capital': 1000000,
#    'end_balance': 2635964.125740285,
#    'max_drawdown': -410846.0115646871,
#    'max_ddpercent': -21.09163801408495,
#    'max_drawdown_duration': 154,
#    'total_net_pnl': 1635964.1257402832,
#    'daily_net_pnl': 1772.4421730663955,
#    'total_commission': 179007.16236518553,
#    'daily_commission': 193.94058761125194,
#    'total_slippage': 128.1425,
#    'daily_slippage': 0.13883261105092093,
#    'total_turnover': 358014324.7303711,
#    'daily_turnover': 387881.1752225039,
#    'total_trade_count': 405,
#    'daily_trade_count': 0.4387865655471289,
#    'total_return': 163.59641257402848,
#    'annual_return': 64.6941393169235,
#    'daily_return': 0.10602687710234925,
#    'return_std': 1.7355056833816562,
#    'sharpe_ratio': 1.1671760353293343,
#    'return_drawdown_ratio': 3.9819398988681747}),
#  ("{'entry_window': 10, 'exit_window': 70, 'atr_window': 12}",
#   3.7172029778826863,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 468,
#    'loss_days': 455,
#    'capital': 1000000,
#    'end_balance': 2542401.4333068067,
#    'max_drawdown': -414936.0264919824,
#    'max_ddpercent': -21.16293460307407,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1542401.4333068063,
#    'daily_net_pnl': 1671.074142260895,
#    'total_commission': 168432.5081970996,
#    'daily_commission': 182.4837575266518,
#    'total_slippage': 119.6225,
#    'daily_slippage': 0.1296018418201517,
#    'total_turnover': 336865016.3941992,
#    'daily_turnover': 364967.51505330356,
#    'total_trade_count': 389,
#    'daily_trade_count': 0.42145178764897073,
#    'total_return': 154.24014333068067,
#    'annual_return': 60.9942061925227,
#    'daily_return': 0.10211139209355283,
#    'return_std': 1.7902013030596842,
#    'sharpe_ratio': 1.089729631761702,
#    'return_drawdown_ratio': 3.7172029778826863}),
#  ("{'entry_window': 70, 'exit_window': 70, 'atr_window': 12}",
#   3.633793822566263,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 466,
#    'loss_days': 451,
#    'capital': 1000000,
#    'end_balance': 2560700.588850801,
#    'max_drawdown': -429496.1863710254,
#    'max_ddpercent': -21.823474809747108,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1560700.5888508004,
#    'daily_net_pnl': 1690.899879578332,
#    'total_commission': 163925.1160179492,
#    'daily_commission': 177.6003423813101,
#    'total_slippage': 116.32310000000001,
#    'daily_slippage': 0.12602719393282774,
#    'total_turnover': 327850232.03589845,
#    'daily_turnover': 355200.6847626202,
#    'total_trade_count': 375,
#    'daily_trade_count': 0.40628385698808234,
#    'total_return': 156.07005888508007,
#    'annual_return': 61.717845604609124,
#    'daily_return': 0.10288840271215562,
#    'return_std': 1.7866205091087477,
#    'sharpe_ratio': 1.1002225507686942,
#    'return_drawdown_ratio': 3.633793822566263}),
#  ("{'entry_window': 60, 'exit_window': 70, 'atr_window': 12}",
#   3.589792481529191,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 466,
#    'loss_days': 452,
#    'capital': 1000000,
#    'end_balance': 2525892.0289260745,
#    'max_drawdown': -425064.13303202135,
#    'max_ddpercent': -21.880007025277585,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1525892.028926074,
#    'daily_net_pnl': 1653.1874636252157,
#    'total_commission': 166302.54594736328,
#    'daily_commission': 180.17610611848676,
#    'total_slippage': 117.91290000000001,
#    'daily_slippage': 0.1277496208017335,
#    'total_turnover': 332605091.8947266,
#    'daily_turnover': 360352.2122369735,
#    'total_trade_count': 381,
#    'daily_trade_count': 0.41278439869989164,
#    'total_return': 152.58920289260746,
#    'annual_return': 60.34134242232039,
#    'daily_return': 0.10140556311849155,
#    'return_std': 1.8158281991338523,
#    'sharpe_ratio': 1.0669239325902646,
#    'return_drawdown_ratio': 3.589792481529191}),
#  ("{'entry_window': 20, 'exit_window': 70, 'atr_window': 12}",
#   3.3806370358612288,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 467,
#    'loss_days': 456,
#    'capital': 1000000,
#    'end_balance': 2521657.021146953,
#    'max_drawdown': -450109.55184051744,
#    'max_ddpercent': -22.792736509578507,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1521657.0211469529,
#    'daily_net_pnl': 1648.5991561722133,
#    'total_commission': 168793.31470148437,
#    'daily_commission': 182.87466381525934,
#    'total_slippage': 119.47130000000001,
#    'daily_slippage': 0.1294380281690141,
#    'total_turnover': 337586629.40296876,
#    'daily_turnover': 365749.3276305187,
#    'total_trade_count': 387,
#    'daily_trade_count': 0.419284940411701,
#    'total_return': 152.16570211469528,
#    'annual_return': 60.173869200285786,
#    'daily_return': 0.10129215553122035,
#    'return_std': 1.7893799401817185,
#    'sharpe_ratio': 1.0814829599682763,
#    'return_drawdown_ratio': 3.3806370358612288}),
#  ("{'entry_window': 30, 'exit_window': 70, 'atr_window': 12}",
#   3.3346370030226415,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 467,
#    'loss_days': 455,
#    'capital': 1000000,
#    'end_balance': 2500951.966981328,
#    'max_drawdown': -450109.55184051767,
#    'max_ddpercent': -22.982963274225032,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1500951.966981328,
#    'daily_net_pnl': 1626.1668114640609,
#    'total_commission': 169016.34940460938,
#    'daily_commission': 183.1163048804002,
#    'total_slippage': 119.6217,
#    'daily_slippage': 0.1296009750812568,
#    'total_turnover': 338032698.80921876,
#    'daily_turnover': 366232.6097608004,
#    'total_trade_count': 387,
#    'daily_trade_count': 0.419284940411701,
#    'total_return': 150.0951966981328,
#    'annual_return': 59.35508861843822,
#    'daily_return': 0.10033049996184228,
#    'return_std': 1.804899610075542,
#    'sharpe_ratio': 1.0620045013358046,
#    'return_drawdown_ratio': 3.3346370030226415}),
#  ("{'entry_window': 50, 'exit_window': 70, 'atr_window': 12}",
#   3.3064143012331493,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 466,
#    'loss_days': 454,
#    'capital': 1000000,
#    'end_balance': 2487032.216141787,
#    'max_drawdown': -449741.64779870096,
#    'max_ddpercent': -23.02953203828299,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1487032.216141787,
#    'daily_net_pnl': 1611.0858246389892,
#    'total_commission': 168628.00917305666,
#    'daily_commission': 182.69556790146984,
#    'total_slippage': 119.3799,
#    'daily_slippage': 0.12933900325027087,
#    'total_turnover': 337256018.34611326,
#    'daily_turnover': 365391.1358029396,
#    'total_trade_count': 385,
#    'daily_trade_count': 0.4171180931744312,
#    'total_return': 148.7032216141787,
#    'annual_return': 58.80463259932309,
#    'daily_return': 0.09972580574387167,
#    'return_std': 1.8298260462864122,
#    'sharpe_ratio': 1.0412240264111505,
#    'return_drawdown_ratio': 3.3064143012331493}),
#  ("{'entry_window': 40, 'exit_window': 70, 'atr_window': 12}",
#   3.3031761041333696,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 467,
#    'loss_days': 455,
#    'capital': 1000000,
#    'end_balance': 2486791.1158817774,
#    'max_drawdown': -450109.55184051744,
#    'max_ddpercent': -23.128545253217027,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1486791.1158817774,
#    'daily_net_pnl': 1610.8246109228357,
#    'total_commission': 168985.88642759767,
#    'daily_commission': 183.08330057161177,
#    'total_slippage': 119.60230000000001,
#    'daily_slippage': 0.12957995666305527,
#    'total_turnover': 337971772.85519534,
#    'daily_turnover': 366166.6011432236,
#    'total_trade_count': 387,
#    'daily_trade_count': 0.419284940411701,
#    'total_return': 148.67911158817773,
#    'annual_return': 58.795098298683506,
#    'daily_return': 0.09971530220569079,
#    'return_std': 1.8222571495522069,
#    'sharpe_ratio': 1.0454387154959393,
#    'return_drawdown_ratio': 3.3031761041333696}),
#  ("{'entry_window': 80, 'exit_window': 60, 'atr_window': 12}",
#   3.04067711287471,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 435,
#    'loss_days': 436,
#    'capital': 1000000,
#    'end_balance': 2469601.488232029,
#    'max_drawdown': -483313.89150446304,
#    'max_ddpercent': -26.03073427301722,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1469601.4882320315,
#    'daily_net_pnl': 1592.2009623315616,
#    'total_commission': 165431.35843046874,
#    'daily_commission': 179.23224098642334,
#    'total_slippage': 118.9599,
#    'daily_slippage': 0.12888396533044422,
#    'total_turnover': 330862716.8609375,
#    'daily_turnover': 358464.48197284667,
#    'total_trade_count': 379,
#    'daily_trade_count': 0.4106175514626219,
#    'total_return': 146.9601488232029,
#    'annual_return': 58.11533512510191,
#    'daily_return': 0.0989637990561558,
#    'return_std': 1.7239743991540755,
#    'sharpe_ratio': 1.0967104425369858,
#    'return_drawdown_ratio': 3.04067711287471}),
#  ("{'entry_window': 60, 'exit_window': 80, 'atr_window': 12}",
#   2.9135896675440454,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 467,
#    'loss_days': 450,
#    'capital': 1000000,
#    'end_balance': 2702624.197736062,
#    'max_drawdown': -584373.3648229397,
#    'max_ddpercent': -28.872767328391024,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1702624.1977360642,
#    'daily_net_pnl': 1844.6632694865268,
#    'total_commission': 139339.2023522168,
#    'daily_commission': 150.96338283013736,
#    'total_slippage': 98.4354,
#    'daily_slippage': 0.10664723726977249,
#    'total_turnover': 278678404.70443356,
#    'daily_turnover': 301926.7656602747,
#    'total_trade_count': 325,
#    'daily_trade_count': 0.352112676056338,
#    'total_return': 170.26241977360624,
#    'annual_return': 67.33020933625815,
#    'daily_return': 0.10873264296276786,
#    'return_std': 1.7030048310197894,
#    'sharpe_ratio': 1.2198052460936797,
#    'return_drawdown_ratio': 2.9135896675440454}),
#  ("{'entry_window': 100, 'exit_window': 60, 'atr_window': 12}",
#   2.8986452905126345,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 395,
#    'loss_days': 430,
#    'capital': 1000000,
#    'end_balance': 2234432.065631952,
#    'max_drawdown': -425865.1686952838,
#    'max_ddpercent': -25.47544809403071,
#    'max_drawdown_duration': 110,
#    'total_net_pnl': 1234432.065631953,
#    'daily_net_pnl': 1337.412855505908,
#    'total_commission': 144480.78350242187,
#    'daily_commission': 156.53389328539748,
#    'total_slippage': 101.73610000000001,
#    'daily_slippage': 0.11022329360780066,
#    'total_turnover': 288961567.0048437,
#    'daily_turnover': 313067.78657079494,
#    'total_trade_count': 345,
#    'daily_trade_count': 0.37378114842903576,
#    'total_return': 123.44320656319523,
#    'annual_return': 48.81556922596562,
#    'daily_return': 0.08812201028162037,
#    'return_std': 1.7697645651370792,
#    'sharpe_ratio': 0.9512952602182647,
#    'return_drawdown_ratio': 2.8986452905126345}),
#  ("{'entry_window': 80, 'exit_window': 80, 'atr_window': 12}",
#   2.8922996149714995,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 466,
#    'loss_days': 451,
#    'capital': 1000000,
#    'end_balance': 2656287.964607957,
#    'max_drawdown': -572654.3529703715,
#    'max_ddpercent': -28.981723064630177,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1656287.9646079587,
#    'daily_net_pnl': 1794.461500116965,
#    'total_commission': 137021.38855532225,
#    'daily_commission': 148.45220861898403,
#    'total_slippage': 96.5992,
#    'daily_slippage': 0.1046578548212351,
#    'total_turnover': 274042777.1106445,
#    'daily_turnover': 296904.41723796807,
#    'total_trade_count': 325,
#    'daily_trade_count': 0.352112676056338,
#    'total_return': 165.62879646079568,
#    'annual_return': 65.49784475426915,
#    'daily_return': 0.10685901566725342,
#    'return_std': 1.7247738899277085,
#    'sharpe_ratio': 1.1836558053800859,
#    'return_drawdown_ratio': 2.8922996149714995}),
#  ("{'entry_window': 70, 'exit_window': 80, 'atr_window': 12}",
#   2.8739285177992757,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 467,
#    'loss_days': 450,
#    'capital': 1000000,
#    'end_balance': 2672266.5841423515,
#    'max_drawdown': -581874.8009163775,
#    'max_ddpercent': -29.16871980429856,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1672266.5841423534,
#    'daily_net_pnl': 1811.773113913709,
#    'total_commission': 138862.29530374025,
#    'daily_commission': 150.44669046992442,
#    'total_slippage': 98.08279999999999,
#    'daily_slippage': 0.1062652221018418,
#    'total_turnover': 277724590.60748047,
#    'daily_turnover': 300893.38093984884,
#    'total_trade_count': 325,
#    'daily_trade_count': 0.352112676056338,
#    'total_return': 167.22665841423515,
#    'annual_return': 66.1297186578503,
#    'daily_return': 0.1075087853384736,
#    'return_std': 1.721613981597742,
#    'sharpe_ratio': 1.1930389052794808,
#    'return_drawdown_ratio': 2.8739285177992757}),
#  ("{'entry_window': 10, 'exit_window': 80, 'atr_window': 12}",
#   2.8514469753388894,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 470,
#    'loss_days': 453,
#    'capital': 1000000,
#    'end_balance': 2633729.4929900365,
#    'max_drawdown': -572947.5270343658,
#    'max_ddpercent': -28.95016027125818,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1633729.4929900388,
#    'daily_net_pnl': 1770.0211191658059,
#    'total_commission': 142535.86592558594,
#    'daily_commission': 154.4267236463553,
#    'total_slippage': 101.4046,
#    'daily_slippage': 0.10986413867822319,
#    'total_turnover': 285071731.85117185,
#    'daily_turnover': 308853.44729271054,
#    'total_trade_count': 333,
#    'daily_trade_count': 0.3607800650054171,
#    'total_return': 163.37294929900366,
#    'annual_return': 64.60577084955183,
#    'daily_return': 0.10593499115144286,
#    'return_std': 1.7241619359280618,
#    'sharpe_ratio': 1.1738370520889336,
#    'return_drawdown_ratio': 2.8514469753388894}),
#  ("{'entry_window': 80, 'exit_window': 70, 'atr_window': 12}",
#   2.787985645584596,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 448,
#    'loss_days': 445,
#    'capital': 1000000,
#    'end_balance': 2425765.953479011,
#    'max_drawdown': -511396.44701436535,
#    'max_ddpercent': -27.461762628401626,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1425765.9534790139,
#    'daily_net_pnl': 1544.708508644652,
#    'total_commission': 152386.59812801756,
#    'daily_commission': 165.09923957531697,
#    'total_slippage': 108.58810000000001,
#    'daily_slippage': 0.1176469122426869,
#    'total_turnover': 304773196.25603515,
#    'daily_turnover': 330198.47915063397,
#    'total_trade_count': 353,
#    'daily_trade_count': 0.38244853737811485,
#    'total_return': 142.5765953479011,
#    'annual_return': 56.38186056552969,
#    'daily_return': 0.0970234452961911,
#    'return_std': 1.787709335642883,
#    'sharpe_ratio': 1.0368745537813409,
#    'return_drawdown_ratio': 2.787985645584596}),
#  ("{'entry_window': 20, 'exit_window': 80, 'atr_window': 12}",
#   2.6924264700572196,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 469,
#    'loss_days': 454,
#    'capital': 1000000,
#    'end_balance': 2637321.2184347734,
#    'max_drawdown': -608121.0523829008,
#    'max_ddpercent': -30.13711425617443,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1637321.2184347752,
#    'daily_net_pnl': 1773.9124793442852,
#    'total_commission': 141960.49131444335,
#    'daily_commission': 153.80334920308056,
#    'total_slippage': 100.12320000000001,
#    'daily_slippage': 0.10847583965330446,
#    'total_turnover': 283920982.6288867,
#    'daily_turnover': 307606.6984061611,
#    'total_trade_count': 333,
#    'daily_trade_count': 0.3607800650054171,
#    'total_return': 163.73212184347733,
#    'annual_return': 64.74780549606633,
#    'daily_return': 0.10615103727742792,
#    'return_std': 1.7115562562644797,
#    'sharpe_ratio': 1.1848939888551187,
#    'return_drawdown_ratio': 2.6924264700572196}),
#  ("{'entry_window': 90, 'exit_window': 60, 'atr_window': 12}",
#   2.6854859965918907,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 421,
#    'loss_days': 441,
#    'capital': 1000000,
#    'end_balance': 2258799.218089735,
#    'max_drawdown': -468741.68016041024,
#    'max_ddpercent': -27.242940327608544,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1258799.2180897365,
#    'daily_net_pnl': 1363.8128039975477,
#    'total_commission': 154523.87227823242,
#    'daily_commission': 167.41481286915754,
#    'total_slippage': 110.2793,
#    'daily_slippage': 0.11947919826652222,
#    'total_turnover': 309047744.55646485,
#    'daily_turnover': 334829.6257383151,
#    'total_trade_count': 365,
#    'daily_trade_count': 0.39544962080173346,
#    'total_return': 125.87992180897349,
#    'annual_return': 49.77916734591042,
#    'daily_return': 0.08929712038100705,
#    'return_std': 1.7487770776954317,
#    'sharpe_ratio': 0.9755497777288343,
#    'return_drawdown_ratio': 2.6854859965918907}),
#  ("{'entry_window': 100, 'exit_window': 70, 'atr_window': 12}",
#   2.6185377067680724,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 411,
#    'loss_days': 438,
#    'capital': 1000000,
#    'end_balance': 2169603.2146606436,
#    'max_drawdown': -446662.7353265141,
#    'max_ddpercent': -27.044186242090156,
#    'max_drawdown_duration': 110,
#    'total_net_pnl': 1169603.2146606448,
#    'daily_net_pnl': 1267.1757471946314,
#    'total_commission': 135176.25050654297,
#    'daily_commission': 146.45314247729465,
#    'total_slippage': 95.3887,
#    'daily_slippage': 0.10334637053087757,
#    'total_turnover': 270352501.01308596,
#    'daily_turnover': 292906.2849545893,
#    'total_trade_count': 323,
#    'daily_trade_count': 0.34994582881906827,
#    'total_return': 116.96032146606434,
#    'annual_return': 46.25191477260399,
#    'daily_return': 0.08493210930751938,
#    'return_std': 1.8472025847927578,
#    'sharpe_ratio': 0.8784232348611296,
#    'return_drawdown_ratio': 2.6185377067680724}),
#  ("{'entry_window': 50, 'exit_window': 80, 'atr_window': 12}",
#   2.5938570064870765,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 467,
#    'loss_days': 452,
#    'capital': 1000000,
#    'end_balance': 2576424.7620391,
#    'max_drawdown': -607753.1483410844,
#    'max_ddpercent': -30.92019443566254,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1576424.7620391012,
#    'daily_net_pnl': 1707.9358201940424,
#    'total_commission': 144753.64237964843,
#    'daily_commission': 156.82951503753893,
#    'total_slippage': 103.54480000000001,
#    'daily_slippage': 0.11218288190682559,
#    'total_turnover': 289507284.7592969,
#    'daily_turnover': 313659.0300750779,
#    'total_trade_count': 333,
#    'daily_trade_count': 0.3607800650054171,
#    'total_return': 157.64247620390995,
#    'annual_return': 62.33965743708248,
#    'daily_return': 0.10355165278513875,
#    'return_std': 1.759660167523035,
#    'sharpe_ratio': 1.124280463439966,
#    'return_drawdown_ratio': 2.5938570064870765}),
#  ("{'entry_window': 30, 'exit_window': 80, 'atr_window': 12}",
#   2.5519448826795426,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 467,
#    'loss_days': 454,
#    'capital': 1000000,
#    'end_balance': 2551891.40767824,
#    'max_drawdown': -608121.0523829008,
#    'max_ddpercent': -31.423312580978024,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1551891.4076782418,
#    'daily_net_pnl': 1681.3558046351482,
#    'total_commission': 145044.1369280078,
#    'daily_commission': 157.14424369231614,
#    'total_slippage': 103.73680000000002,
#    'daily_slippage': 0.11239089924160349,
#    'total_turnover': 290088273.8560156,
#    'daily_turnover': 314288.4873846323,
#    'total_trade_count': 335,
#    'daily_trade_count': 0.3629469122426869,
#    'total_return': 155.189140767824,
#    'annual_return': 61.369486869182836,
#    'daily_return': 0.10251504671603202,
#    'return_std': 1.772015923073049,
#    'sharpe_ratio': 1.1052650216033386,
#    'return_drawdown_ratio': 2.5519448826795426}),
#  ("{'entry_window': 40, 'exit_window': 80, 'atr_window': 12}",
#   2.547198507585319,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 467,
#    'loss_days': 454,
#    'capital': 1000000,
#    'end_balance': 2549005.037060935,
#    'max_drawdown': -608121.0523829004,
#    'max_ddpercent': -31.47024945987795,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1549005.0370609374,
#    'daily_net_pnl': 1678.2286425362267,
#    'total_commission': 145107.99691093748,
#    'daily_commission': 157.21343110610778,
#    'total_slippage': 103.7672,
#    'daily_slippage': 0.11242383531960998,
#    'total_turnover': 290215993.821875,
#    'daily_turnover': 314426.86221221555,
#    'total_trade_count': 335,
#    'daily_trade_count': 0.3629469122426869,
#    'total_return': 154.9005037060935,
#    'annual_return': 61.25534545257218,
#    'daily_return': 0.10239243444712708,
#    'return_std': 1.7799982525392197,
#    'sharpe_ratio': 1.0989924909184103,
#    'return_drawdown_ratio': 2.547198507585319}),
#  ("{'entry_window': 90, 'exit_window': 70, 'atr_window': 12}",
#   2.533240116227586,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 439,
#    'loss_days': 446,
#    'capital': 1000000,
#    'end_balance': 2249648.768609189,
#    'max_drawdown': -493300.5602604002,
#    'max_ddpercent': -28.420742866810837,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1249648.7686091894,
#    'daily_net_pnl': 1353.8989909091977,
#    'total_commission': 141910.60894002928,
#    'daily_commission': 153.74930546048677,
#    'total_slippage': 100.4379,
#    'daily_slippage': 0.10881679306608884,
#    'total_turnover': 283821217.8800586,
#    'daily_turnover': 307498.61092097353,
#    'total_trade_count': 339,
#    'daily_trade_count': 0.36728060671722645,
#    'total_return': 124.96487686091888,
#    'annual_return': 49.417313168185686,
#    'daily_return': 0.0888573314899953,
#    'return_std': 1.8000021028512267,
#    'sharpe_ratio': 0.9431194173544409,
#    'return_drawdown_ratio': 2.533240116227586}),
#  ("{'entry_window': 90, 'exit_window': 80, 'atr_window': 12}",
#   2.4919667792744065,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 455,
#    'loss_days': 454,
#    'capital': 1000000,
#    'end_balance': 2390169.8316170797,
#    'max_drawdown': -557860.4992566796,
#    'max_ddpercent': -31.511199329250772,
#    'max_drawdown_duration': 112,
#    'total_net_pnl': 1390169.8316170801,
#    'daily_net_pnl': 1506.1428294876275,
#    'total_commission': 130743.80718995117,
#    'daily_commission': 141.65092869983874,
#    'total_slippage': 92.2334,
#    'daily_slippage': 0.09992784398699892,
#    'total_turnover': 261487614.37990233,
#    'daily_turnover': 283301.8573996775,
#    'total_trade_count': 315,
#    'daily_trade_count': 0.3412784398699892,
#    'total_return': 139.016983161708,
#    'annual_return': 54.97421327629839,
#    'daily_return': 0.0954218300254434,
#    'return_std': 1.8019657950262022,
#    'sharpe_ratio': 1.011690403854403,
#    'return_drawdown_ratio': 2.4919667792744065}),
#  ("{'entry_window': 60, 'exit_window': 100, 'atr_window': 12}",
#   2.443989166507933,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 448,
#    'loss_days': 470,
#    'capital': 1000000,
#    'end_balance': 2227335.5337448334,
#    'max_drawdown': -502185.3413116797,
#    'max_ddpercent': -33.524692285826575,
#    'max_drawdown_duration': 110,
#    'total_net_pnl': 1227335.533744834,
#    'daily_net_pnl': 1329.7243052490076,
#    'total_commission': 116574.99137469727,
#    'daily_commission': 126.30009899750517,
#    'total_slippage': 82.6524,
#    'daily_slippage': 0.08954756229685808,
#    'total_turnover': 233149982.74939454,
#    'daily_turnover': 252600.19799501033,
#    'total_trade_count': 279,
#    'daily_trade_count': 0.30227518959913324,
#    'total_return': 122.73355337448334,
#    'annual_return': 48.53493714158875,
#    'daily_return': 0.08777736854181435,
#    'return_std': 2.09271149646106,
#    'sharpe_ratio': 0.8013451802406748,
#    'return_drawdown_ratio': 2.443989166507933}),
#  ("{'entry_window': 70, 'exit_window': 100, 'atr_window': 12}",
#   2.4284612938122856,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 448,
#    'loss_days': 470,
#    'capital': 1000000,
#    'end_balance': 2213109.502777099,
#    'max_drawdown': -499538.331480967,
#    'max_ddpercent': -33.7278965651514,
#    'max_drawdown_duration': 110,
#    'total_net_pnl': 1213109.5027770996,
#    'daily_net_pnl': 1314.3114872991328,
#    'total_commission': 116054.94082055664,
#    'daily_commission': 125.73666394426505,
#    'total_slippage': 82.279,
#    'daily_slippage': 0.0891430119176598,
#    'total_turnover': 232109881.64111328,
#    'daily_turnover': 251473.3278885301,
#    'total_trade_count': 279,
#    'daily_trade_count': 0.30227518959913324,
#    'total_return': 121.31095027770994,
#    'annual_return': 47.97236928641834,
#    'daily_return': 0.08708316467010525,
#    'return_std': 2.1101701362213268,
#    'sharpe_ratio': 0.7884300400326362,
#    'return_drawdown_ratio': 2.4284612938122856}),
#  ("{'entry_window': 80, 'exit_window': 100, 'atr_window': 12}",
#   2.3727441828137583,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 446,
#    'loss_days': 472,
#    'capital': 1000000,
#    'end_balance': 2185276.670113954,
#    'max_drawdown': -499538.3314809669,
#    'max_ddpercent': -34.01798028285646,
#    'max_drawdown_duration': 110,
#    'total_net_pnl': 1185276.6701139552,
#    'daily_net_pnl': 1284.1567390183695,
#    'total_commission': 115671.89236026368,
#    'daily_commission': 125.32166019530193,
#    'total_slippage': 81.9936,
#    'daily_slippage': 0.08883380281690141,
#    'total_turnover': 231343784.72052732,
#    'daily_turnover': 250643.32039060383,
#    'total_trade_count': 279,
#    'daily_trade_count': 0.30227518959913324,
#    'total_return': 118.52766701139541,
#    'annual_return': 46.871720974170444,
#    'daily_return': 0.08571197307382372,
#    'return_std': 2.1244104472310377,
#    'sharpe_ratio': 0.7708138267004341,
#    'return_drawdown_ratio': 2.3727441828137583}),
#  ("{'entry_window': 100, 'exit_window': 80, 'atr_window': 12}",
#   2.3699111712054712,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 429,
#    'loss_days': 448,
#    'capital': 1000000,
#    'end_balance': 2211176.425472129,
#    'max_drawdown': -511064.0602010647,
#    'max_ddpercent': -31.226239647519982,
#    'max_drawdown_duration': 110,
#    'total_net_pnl': 1211176.4254721287,
#    'daily_net_pnl': 1312.2171456902802,
#    'total_commission': 127655.09894193358,
#    'daily_commission': 138.30454923286413,
#    'total_slippage': 90.38999999999999,
#    'daily_slippage': 0.09793066088840735,
#    'total_turnover': 255310197.8838672,
#    'daily_turnover': 276609.0984657283,
#    'total_trade_count': 305,
#    'daily_trade_count': 0.3304442036836403,
#    'total_return': 121.11764254721291,
#    'annual_return': 47.89592581769524,
# ...
#    'return_std': 2.0626320725555947,
#    'sharpe_ratio': 0.25092505420156347,
#    'return_drawdown_ratio': 0.4529405137549558}),
#  ("{'entry_window': 30, 'exit_window': 20, 'atr_window': 12}",
#   0.3293576747551859,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 347,
#    'loss_days': 544,
#    'capital': 1000000,
#    'end_balance': 1218615.9368066508,
#    'max_drawdown': -663764.5136678515,
#    'max_ddpercent': -40.6195266697442,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': 218615.93680665037,
#    'daily_net_pnl': 236.85366934631676,
#    'total_commission': 580063.0993894434,
#    'daily_commission': 628.4540621770784,
#    'total_slippage': 403.5248,
#    'daily_slippage': 0.4371882990249188,
#    'total_turnover': 1160126198.7788868,
#    'daily_turnover': 1256908.124354157,
#    'total_trade_count': 1187,
#    'daily_trade_count': 1.28602383531961,
#    'total_return': 21.86159368066509,
#    'annual_return': 8.645158931140584,
#    'daily_return': 0.024522653566314136,
#    'return_std': 2.161598776782616,
#    'sharpe_ratio': 0.21673987031505138,
#    'return_drawdown_ratio': 0.3293576747551859}),
#  ("{'entry_window': 20, 'exit_window': 40, 'atr_window': 12}",
#   0.24397816812059764,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 429,
#    'loss_days': 494,
#    'capital': 1000000,
#    'end_balance': 1226371.314919277,
#    'max_drawdown': -927834.3085492093,
#    'max_ddpercent': -51.54539927975029,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': 226371.31491927744,
#    'daily_net_pnl': 245.256029164981,
#    'total_commission': 376500.23171978514,
#    'daily_commission': 407.9092434667228,
#    'total_slippage': 264.71590000000003,
#    'daily_slippage': 0.2867994582881907,
#    'total_turnover': 753000463.4395703,
#    'daily_turnover': 815818.4869334457,
#    'total_trade_count': 759,
#    'daily_trade_count': 0.8223185265438786,
#    'total_return': 22.63713149192772,
#    'annual_return': 8.951845064521795,
#    'daily_return': 0.023391725779625953,
#    'return_std': 2.1814941667905425,
#    'sharpe_ratio': 0.20485880747666665,
#    'return_drawdown_ratio': 0.24397816812059764}),
#  ("{'entry_window': 10, 'exit_window': 40, 'atr_window': 12}",
#   0.2080743330590028,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 428,
#    'loss_days': 495,
#    'capital': 1000000,
#    'end_balance': 1193898.5210128613,
#    'max_drawdown': -931871.4046190333,
#    'max_ddpercent': -52.52447805523261,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': 193898.5210128615,
#    'daily_net_pnl': 210.07423728370694,
#    'total_commission': 380547.61919885746,
#    'daily_commission': 412.2942786553169,
#    'total_slippage': 268.7443,
#    'daily_slippage': 0.29116392199349944,
#    'total_turnover': 761095238.3977149,
#    'daily_turnover': 824588.5573106336,
#    'total_trade_count': 767,
#    'daily_trade_count': 0.8309859154929577,
#    'total_return': 19.38985210128612,
#    'annual_return': 7.667709660855291,
#    'daily_return': 0.020484289370249098,
#    'return_std': 2.223207622786899,
#    'sharpe_ratio': 0.17603025237364142,
#    'return_drawdown_ratio': 0.2080743330590028}),
#  ("{'entry_window': 30, 'exit_window': 40, 'atr_window': 12}",
#   0.1864960216768912,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 428,
#    'loss_days': 495,
#    'capital': 1000000,
#    'end_balance': 1173837.435427519,
#    'max_drawdown': -932124.0950045412,
#    'max_ddpercent': -52.3124642709565,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': 173837.4354275195,
#    'daily_net_pnl': 188.33958334509154,
#    'total_commission': 374518.13184123044,
#    'daily_commission': 405.7617896438033,
#    'total_slippage': 263.3857,
#    'daily_slippage': 0.28535828819068254,
#    'total_turnover': 749036263.6824609,
#    'daily_turnover': 811523.5792876066,
#    'total_trade_count': 757,
#    'daily_trade_count': 0.8201516793066089,
#    'total_return': 17.383743542751894,
#    'annual_return': 6.87439479209582,
#    'daily_return': 0.018648343602203372,
#    'return_std': 2.2144040432695844,
#    'sharpe_ratio': 0.16089028799988453,
#    'return_drawdown_ratio': 0.1864960216768912}),
#  ("{'entry_window': 40, 'exit_window': 10, 'atr_window': 12}",
#   0.17543939945896278,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 302,
#    'loss_days': 501,
#    'capital': 1000000,
#    'end_balance': 1102801.642313867,
#    'max_drawdown': -585966.6792687206,
#    'max_ddpercent': -42.738335115582444,
#    'max_drawdown_duration': 114,
#    'total_net_pnl': 102801.64231386699,
#    'daily_net_pnl': 111.37772731729902,
#    'total_commission': 635947.1215392578,
#    'daily_commission': 689.0001316785025,
#    'total_slippage': 449.05809999999997,
#    'daily_slippage': 0.48652015167930657,
#    'total_turnover': 1271894243.0785155,
#    'daily_turnover': 1378000.2633570048,
#    'total_trade_count': 1301,
#    'daily_trade_count': 1.409534127843987,
#    'total_return': 10.280164231386713,
#    'annual_return': 4.065287047081419,
#    'daily_return': 0.012212733883023639,
#    'return_std': 1.7932819608780342,
#    'sharpe_ratio': 0.13011002079603562,
#    'return_drawdown_ratio': 0.17543939945896278}),
#  ("{'entry_window': 50, 'exit_window': 40, 'atr_window': 12}",
#   0.17488211133915268,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 403,
#    'loss_days': 489,
#    'capital': 1000000,
#    'end_balance': 1137442.9880772757,
#    'max_drawdown': -785917.9365162693,
#    'max_ddpercent': -49.33988058613595,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': 137442.98807727534,
#    'daily_net_pnl': 148.90897949867318,
#    'total_commission': 319428.5061172559,
#    'daily_commission': 346.0763879926933,
#    'total_slippage': 223.34520000000003,
#    'daily_slippage': 0.24197746478873244,
#    'total_turnover': 638857012.2345116,
#    'daily_turnover': 692152.7759853863,
#    'total_trade_count': 666,
#    'daily_trade_count': 0.7215601300108342,
#    'total_return': 13.744298807727562,
#    'annual_return': 5.435177751701582,
#    'daily_return': 0.01523698667816468,
#    'return_std': 2.2720841774899165,
#    'sharpe_ratio': 0.12812123099629047,
#    'return_drawdown_ratio': 0.17488211133915268}),
#  ("{'entry_window': 40, 'exit_window': 40, 'atr_window': 12}",
#   0.10803014657572335,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 425,
#    'loss_days': 498,
#    'capital': 1000000,
#    'end_balance': 1102192.0113655669,
#    'max_drawdown': -945958.2774326367,
#    'max_ddpercent': -54.44115281246991,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': 102192.01136556652,
#    'daily_net_pnl': 110.7172387492595,
#    'total_commission': 372734.9718250586,
#    'daily_commission': 403.8298719664773,
#    'total_slippage': 262.17470000000003,
#    'daily_slippage': 0.28404626218851575,
#    'total_turnover': 745469943.6501172,
#    'daily_turnover': 807659.7439329546,
#    'total_trade_count': 753,
#    'daily_trade_count': 0.8158179848320694,
#    'total_return': 10.219201136556677,
#    'annual_return': 4.041179214347982,
#    'daily_return': 0.011825233461213093,
#    'return_std': 2.300655690128637,
#    'sharpe_ratio': 0.098198426226286,
#    'return_drawdown_ratio': 0.10803014657572335}),
#  ("{'entry_window': 30, 'exit_window': 10, 'atr_window': 12}",
#   -0.05008487655624519,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 325,
#    'loss_days': 530,
#    'capital': 1000000,
#    'end_balance': 967661.7955071782,
#    'max_drawdown': -645668.0482481932,
#    'max_ddpercent': -51.71097563602738,
#    'max_drawdown_duration': 484,
#    'total_net_pnl': -32338.204492822522,
#    'daily_net_pnl': -35.035974531768716,
#    'total_commission': 735092.268413916,
#    'daily_commission': 796.416325475532,
#    'total_slippage': 522.5852,
#    'daily_slippage': 0.5661811484290358,
#    'total_turnover': 1470184536.827832,
#    'daily_turnover': 1592832.650951064,
#    'total_trade_count': 1521,
#    'daily_trade_count': 1.647887323943662,
#    'total_return': -3.2338204492821876,
#    'annual_return': -1.2788130704095326,
#    'daily_return': -0.000646284962335821,
#    'return_std': 2.219889481266722,
#    'sharpe_ratio': -0.005562104317684601,
#    'return_drawdown_ratio': -0.05008487655624519}),
#  ("{'entry_window': 50, 'exit_window': 30, 'atr_window': 12}",
#   -0.13372781757397012,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 357,
#    'loss_days': 504,
#    'capital': 1000000,
#    'end_balance': 894284.1464075927,
#    'max_drawdown': -790530.0146989357,
#    'max_ddpercent': -54.67041759445215,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': -105715.85359240719,
#    'daily_net_pnl': -114.53505264616163,
#    'total_commission': 353541.91691623535,
#    'daily_commission': 383.035662964502,
#    'total_slippage': 246.9036,
#    'daily_slippage': 0.26750119176598053,
#    'total_turnover': 707083833.8324707,
#    'daily_turnover': 766071.325929004,
#    'total_trade_count': 750,
#    'daily_trade_count': 0.8125677139761647,
#    'total_return': -10.571585359240732,
#    'annual_return': -4.180529421584905,
#    'daily_return': -0.00966707045993349,
#    'return_std': 2.4916084414861412,
#    'sharpe_ratio': -0.07412445661136267,
#    'return_drawdown_ratio': -0.13372781757397012}),
#  ("{'entry_window': 40, 'exit_window': 30, 'atr_window': 12}",
#   -0.18443265552323976,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 386,
#    'loss_days': 521,
#    'capital': 1000000,
#    'end_balance': 827066.3904864356,
#    'max_drawdown': -937651.7896082322,
#    'max_ddpercent': -59.44623219243711,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': -172933.60951356438,
#    'daily_net_pnl': -187.3603570027783,
#    'total_commission': 420270.29713934567,
#    'daily_commission': 455.33076613146875,
#    'total_slippage': 294.71130000000005,
#    'daily_slippage': 0.3192971830985916,
#    'total_turnover': 840540594.2786914,
#    'daily_turnover': 910661.5322629376,
#    'total_trade_count': 865,
#    'daily_trade_count': 0.9371614301191766,
#    'total_return': -17.29336095135644,
#    'annual_return': -6.838653030601409,
#    'daily_return': -0.01813458202319275,
#    'return_std': 2.5718213081702617,
#    'sharpe_ratio': -0.1347141428465476,
#    'return_drawdown_ratio': -0.18443265552323976}),
#  ("{'entry_window': 20, 'exit_window': 10, 'atr_window': 12}",
#   -0.2447428326270828,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 370,
#    'loss_days': 547,
#    'capital': 1000000,
#    'end_balance': 818436.326020068,
#    'max_drawdown': -741854.9177968458,
#    'max_ddpercent': -58.350593795424366,
#    'max_drawdown_duration': 172,
#    'total_net_pnl': -181563.6739799317,
#    'daily_net_pnl': -196.7103726759823,
#    'total_commission': 971890.9331197755,
#    'daily_commission': 1052.9695916790633,
#    'total_slippage': 681.6242000000001,
#    'daily_slippage': 0.7384877573131096,
#    'total_turnover': 1943781866.2395506,
#    'daily_turnover': 2105939.1833581263,
#    'total_trade_count': 2007,
#    'daily_trade_count': 2.174431202600217,
#    'total_return': -18.1563673979932,
#    'annual_return': -7.179928602673368,
#    'daily_return': -0.019328691024838637,
#    'return_std': 2.518168663552057,
#    'sharpe_ratio': -0.1466439197951422,
#    'return_drawdown_ratio': -0.2447428326270828}),
#  ("{'entry_window': 30, 'exit_window': 30, 'atr_window': 12}",
#   -0.40665741960935314,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 395,
#    'loss_days': 526,
#    'capital': 1000000,
#    'end_balance': 616738.5096087795,
#    'max_drawdown': -942467.7183054787,
#    'max_ddpercent': -66.3816175191326,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': -383261.49039122066,
#    'daily_net_pnl': -415.234550803056,
#    'total_commission': 459811.83129981445,
#    'daily_commission': 498.17099815797883,
#    'total_slippage': 323.07539999999995,
#    'daily_slippage': 0.35002751895991324,
#    'total_turnover': 919623662.5996289,
#    'daily_turnover': 996341.9963159576,
#    'total_trade_count': 971,
#    'daily_trade_count': 1.0520043336944744,
#    'total_return': -38.32614903912206,
#    'annual_return': -15.15606110431154,
#    'daily_return': -0.04883542639187228,
#    'return_std': 3.0666629252188957,
#    'sharpe_ratio': -0.30423934222163745,
#    'return_drawdown_ratio': -0.40665741960935314}),
#  ("{'entry_window': 20, 'exit_window': 30, 'atr_window': 12}",
#   -0.41435799584842736,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 399,
#    'loss_days': 524,
#    'capital': 1000000,
#    'end_balance': 606336.3121704395,
#    'max_drawdown': -950056.9357265724,
#    'max_ddpercent': -67.69763654012705,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': -393663.6878295607,
#    'daily_net_pnl': -426.5045371934569,
#    'total_commission': 465863.8121381543,
#    'daily_commission': 504.727857137762,
#    'total_slippage': 327.12699999999995,
#    'daily_slippage': 0.3544171180931744,
#    'total_turnover': 931727624.2763085,
#    'daily_turnover': 1009455.7142755239,
#    'total_trade_count': 985,
#    'daily_trade_count': 1.067172264355363,
#    'total_return': -39.36636878295605,
#    'annual_return': -15.56741560756117,
#    'daily_return': -0.0506783648510632,
#    'return_std': 3.1570524690259423,
#    'sharpe_ratio': -0.30668125110634614,
#    'return_drawdown_ratio': -0.41435799584842736}),
#  ("{'entry_window': 10, 'exit_window': 10, 'atr_window': 12}",
#   -0.42381193395589034,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 399,
#    'loss_days': 524,
#    'capital': 1000000,
#    'end_balance': 636873.0062016016,
#    'max_drawdown': -856811.6296512597,
#    'max_ddpercent': -77.78190657182319,
#    'max_drawdown_duration': 528,
#    'total_net_pnl': -363126.9937983985,
#    'daily_net_pnl': -393.42036164506874,
#    'total_commission': 1304682.4914046484,
#    'daily_commission': 1413.523826007203,
#    'total_slippage': 916.2088000000001,
#    'daily_slippage': 0.9926422535211269,
#    'total_turnover': 2609364982.809297,
#    'daily_turnover': 2827047.6520144064,
#    'total_trade_count': 2755,
#    'daily_trade_count': 2.9848320693391117,
#    'total_return': -36.31269937983984,
#    'annual_return': -14.359843200045008,
#    'daily_return': -0.046276960507182406,
#    'return_std': 4.093343653458994,
#    'sharpe_ratio': -0.2159897052235009,
#    'return_drawdown_ratio': -0.42381193395589034}),
#  ("{'entry_window': 10, 'exit_window': 30, 'atr_window': 12}",
#   -0.42728201784152803,
#   {'start_date': datetime.date(2022, 1, 11),
#    'end_date': datetime.date(2024, 7, 23),
#    'total_days': 923,
#    'profit_days': 396,
#    'loss_days': 527,
#    'capital': 1000000,
#    'end_balance': 575365.5338578417,
#    'max_drawdown': -993803.737136553,
#    'max_ddpercent': -70.02914768284053,
#    'max_drawdown_duration': 208,
#    'total_net_pnl': -424634.4661421579,
#    'daily_net_pnl': -460.0590099048298,
#    'total_commission': 472839.331794502,
#    'daily_commission': 512.285299885701,
#    'total_slippage': 332.613,
#    'daily_slippage': 0.36036078006500544,
#    'total_turnover': 945678663.5890039,
#    'daily_turnover': 1024570.5997714018,
#    'total_trade_count': 999,
#    'daily_trade_count': 1.0823401950162514,
#    'total_return': -42.463446614215826,
#    'annual_return': -16.7921538615263,
#    'daily_return': -0.05635867393368398,
#    'return_std': 3.232851512568191,
#    'sharpe_ratio': -0.3330592046896943,
#    'return_drawdown_ratio': -0.42728201784152803})]
